# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.ml.feature import Imputer
import pyspark.sql.functions as F
from delta import *

# %%
builder = SparkSession.builder \
    .appName("Business to Silver") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:3.1.0") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
def load_business_data(spark, path):
    schema = StructType([
        StructField("business_id", StringType(), True),
        StructField("name", StringType(), True),
        StructField("address", StringType(), True),
        StructField("city", StringType(), True),
        StructField("state", StringType(), True),
        StructField("postal_code", StringType(), True),
        StructField("latitude", DoubleType(), True),
        StructField("longitude", DoubleType(), True),
        StructField("stars", DoubleType(), True),
        StructField("review_count", IntegerType(), True),
        StructField("is_open", IntegerType(), True),
        StructField("attributes", MapType(StringType(), StringType()), True),
        StructField("categories", StringType(), True),
        StructField("hours", MapType(StringType(), StringType()), True)
    ])
    return spark.read.json(path, schema=schema)

df = load_business_data(spark, "D:/Project/delta_lake/bronze/yelp_academic_dataset_business.json")
df.show(5)
# Out:
# +--------------------+--------------------+--------------------+-------------+-----+-----------+----------+------------+-----+------------+-------+--------------------+--------------------+--------------------+
# |         business_id|                name|             address|         city|state|postal_code|  latitude|   longitude|stars|review_count|is_open|          attributes|          categories|               hours|
# +--------------------+--------------------+--------------------+-------------+-----+-----------+----------+------------+-----+------------+-------+--------------------+--------------------+--------------------+
# |Pns2l4eNsfO8kk83d...|Abby Rappoport, L...|1616 Chapala St, ...|Santa Barbara|   CA|      93101|34.4266787|-119.7111968|  5.0|           7|      0|{ByAppointmentOnl...|Doctors, Traditio...|                NULL|
# |mpf3x-BjTdTEA3yCZ...|       The UPS Store|87 Grasso Plaza S...|       Affton|   MO|      63123| 38.551126|  -90.335695|  3.0|          15|      1|{BusinessAcceptsC...|Shipping Centers,...|{Monday -> 0:0-0:...|
# |tUFrWirKiKi_TAnsV...|              Target|5255 E Broadway Blvd|       Tucson|   AZ|      85711| 32.223236| -110.880452|  3.5|          22|      0|{BikeParking -> T...|Department Stores...|{Monday -> 8:0-22...|
# |MTSW4McQd7CbVtyjq...|  St Honore Pastries|         935 Race St| Philadelphia|   PA|      19107|39.9555052| -75.1555641|  4.0|          80|      1|{RestaurantsDeliv...|Restaurants, Food...|{Monday -> 7:0-20...|
# |mWMc6_wTdE0EUBKIG...|Perkiomen Valley ...|       101 Walnut St|   Green Lane|   PA|      18054|40.3381827| -75.4716585|  4.5|          13|      1|{BusinessAcceptsC...|Brewpubs, Breweri...|{Wednesday -> 14:...|
# +--------------------+--------------------+--------------------+-------------+-----+-----------+----------+------------+-----+------------+-------+--------------------+--------------------+--------------------+
# only showing top 5 rows

# %%
attribute_list = [
    "AcceptsInsurance", "AgesAllowed", "Alcohol", "Ambience", "BYOB", 
    "BYOBCorkage", "BestNights", "BikeParking", "BusinessAcceptsBitcoin", 
    "BusinessAcceptsCreditCards", "BusinessParking", "ByAppointmentOnly", 
    "Caters", "CoatCheck", "Corkage", "DietaryRestrictions", "DogsAllowed", 
    "DriveThru", "GoodForDancing", "GoodForKids", "GoodForMeal", 
    "HairSpecializesIn", "HappyHour", "HasTV", "Music", "NoiseLevel", 
    "Open24Hours", "OutdoorSeating", "RestaurantsAttire", "RestaurantsCounterService", 
    "RestaurantsDelivery", "RestaurantsGoodForGroups", "RestaurantsPriceRange2", 
    "RestaurantsReservations", "RestaurantsTableService", "RestaurantsTakeOut", 
    "Smoking", "WheelchairAccessible", "WiFi"
]

# Function to extract attribute values
def extract_attributes(df, attr_list):
    # Create a copy of the original dataframe
    result_df = df
    
    # Extract each attribute as a separate column
    for attr in attr_list:
        result_df = result_df.withColumn(
            f"attr_{attr}", 
            when(col("attributes").getItem(attr).isNotNull(), col("attributes").getItem(attr))
            .otherwise(lit(None))
        )
    
    return result_df

# Apply the extraction
df = extract_attributes(df, attribute_list)

# Show the result with some of the extracted columns
df.show(20)
# Out:
# +--------------------+--------------------+--------------------+--------------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+--------------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+--------------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+
# |         business_id|                name|             address|          city|state|postal_code|     latitude|     longitude|stars|review_count|is_open|          attributes|          categories|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|       attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|    attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi|
# +--------------------+--------------------+--------------------+--------------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+--------------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+--------------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+
# |Pns2l4eNsfO8kk83d...|Abby Rappoport, L...|1616 Chapala St, ...| Santa Barbara|   CA|      93101|   34.4266787|  -119.7111968|  5.0|           7|      0|{ByAppointmentOnl...|Doctors, Traditio...|                NULL|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  True|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |mpf3x-BjTdTEA3yCZ...|       The UPS Store|87 Grasso Plaza S...|        Affton|   MO|      63123|    38.551126|    -90.335695|  3.0|          15|      1|{BusinessAcceptsC...|Shipping Centers,...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |tUFrWirKiKi_TAnsV...|              Target|5255 E Broadway Blvd|        Tucson|   AZ|      85711|    32.223236|   -110.880452|  3.5|          22|      0|{BikeParking -> T...|Department Stores...|{Monday -> 8:0-22...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                 False|      False|         False|        NULL|                    NULL|           False|          NULL|               NULL|            NULL|                NULL|                  NULL|         False|     False|      NULL|           NULL|            NULL|              False|                  NULL|                          NULL|                   False|                         NULL|                          2|                       False|                        NULL|                  False|        NULL|                     True|    u'no'|
# |MTSW4McQd7CbVtyjq...|  St Honore Pastries|         935 Race St|  Philadelphia|   PA|      19107|   39.9555052|   -75.1555641|  4.0|          80|      1|{RestaurantsDeliv...|Restaurants, Food...|{Monday -> 7:0-20...|                 NULL|            NULL|     u'none'|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                          False|{'garage': False,...|                 False|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|              False|                  NULL|                          NULL|                   False|                         NULL|                          1|                        NULL|                        NULL|                   True|        NULL|                     NULL|  u'free'|
# |mWMc6_wTdE0EUBKIG...|Perkiomen Valley ...|       101 Walnut St|    Green Lane|   PA|      18054|   40.3381827|   -75.4716585|  4.5|          13|      1|{BusinessAcceptsC...|Brewpubs, Breweri...|{Wednesday -> 14:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': None, ...|                  NULL|      False|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   True|        NULL|                     True|     NULL|
# |CF33F8-E6oudUQ46H...|      Sonic Drive-In|       615 S Main St|  Ashland City|   TN|      37015|    36.269593|    -87.058943|  2.0|           6|      1|{BusinessParking ...|Burgers, Fast Foo...|{Monday -> 0:0-0:...|                 NULL|            NULL|     u'none'|                None|     NULL|            NULL|           NULL|           False|                       NULL|                           True|                None|                 False|      False|         False|        NULL|                    NULL|           False|          True|               NULL|            True|                NULL|                  NULL|         False|      True|      NULL|           NULL|            NULL|               True|             u'casual'|                          NULL|                    True|                         True|                          1|                       False|                       False|                   True|        NULL|                     True|    u'no'|
# |n_0UpQx1hsNbnPUSl...|     Famous Footwear|8522 Eager Road, ...|     Brentwood|   MO|      63144|    38.627695|    -90.340465|  2.5|          13|      1|{BusinessAcceptsC...|Sporting Goods, F...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |qkRM_2X51Yqxk3btl...|      Temple Beth-El|  400 Pasadena Ave S|St. Petersburg|   FL|      33707|     27.76659|    -82.732983|  3.5|           5|      1|                NULL|Synagogues, Relig...|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |k0hlBqXX-Bt0vf1op...|Tsevi's Pub And G...|   8025 Mackenzie Rd|        Affton|   MO|      63123|   38.5651648|   -90.3210868|  3.0|          19|      0|{Caters -> True, ...|Pubs, Restaurants...|                NULL|                 NULL|            NULL| u'full_bar'|{'romantic': Fals...|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{'garage': False,...|                  NULL|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|                NULL|                  NULL|          NULL|      True|      NULL|     u'average'|            NULL|               True|             u'casual'|                          NULL|                   False|                         True|                          1|                       False|                        NULL|                   True|        NULL|                     NULL|  u'free'|
# |bBDDEgkFA1Otx9Lfe...|      Sonic Drive-In| 2312 Dickerson Pike|     Nashville|   TN|      37207|   36.2081024|   -86.7681696|  1.5|          10|      1|{RestaurantsAttir...|Ice Cream & Froze...|{Monday -> 0:0-0:...|                 NULL|            NULL|     u'none'|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{'garage': False,...|                 False|      False|         False|        NULL|                    NULL|           False|          True|               NULL|            True|                NULL|                  NULL|         False|      True|      NULL|           NULL|            NULL|               True|              'casual'|                          NULL|                    True|                        False|                          1|                       False|                       False|                   True|        NULL|                     True|    u'no'|
# |UJsufbvfyfONHeWdv...|           Marshalls|21705 Village Lak...| Land O' Lakes|   FL|      34639|28.1904587953|-82.4573802199|  3.5|           6|      1|{RestaurantsPrice...|Department Stores...|{Monday -> 9:30-2...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |eEOYSgkmpB90uNA7l...|Vietnamese Food T...|                    |     Tampa Bay|   FL|      33602|   27.9552692|   -82.4563199|  4.0|          10|      1|{Alcohol -> 'none...|Vietnamese, Food,...|{Monday -> 11:0-1...|                 NULL|            NULL|      'none'|{'touristy': Fals...|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|{'dessert': False...|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               None|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                       False|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |il_Ro8jwPlHresjw9...|             Denny's|        8901 US 31 S|  Indianapolis|   IN|      46227|39.6371332838| -86.127217412|  2.5|          28|      1|{RestaurantsReser...|American (Traditi...|{Monday -> 6:0-22...|                 NULL|            NULL|      'none'|{'touristy': None...|     NULL|            NULL|           NULL|           False|                       NULL|                           True|{'garage': None, ...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|{'dessert': False...|                  NULL|          NULL|      True|      NULL|           NULL|            NULL|              False|              'casual'|                          NULL|                    True|                         True|                          1|                       False|                        NULL|                   True|        NULL|                     NULL|    u'no'|
# |jaxMSoInw8Poo3XeM...|        Adams Dental|   15 N Missouri Ave|    Clearwater|   FL|      33755|    27.966235|    -82.787412|  5.0|          10|      1|{ByAppointmentOnl...|General Dentistry...|{Monday -> 7:30-1...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  True|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |0bPLkL0QhhPO5kt1_...|Zio's Italian Market|       2575 E Bay Dr|         Largo|   FL|      33771|   27.9161159|   -82.7604608|  4.5|         100|      0|{OutdoorSeating -...|Food, Delis, Ital...|{Monday -> 10:0-1...|                 NULL|            NULL|     u'none'|{'romantic': Fals...|     NULL|            NULL|           NULL|            True|                      False|                           True|{'garage': False,...|                  NULL|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|{'dessert': False...|                  NULL|          NULL|      True|      NULL|     u'average'|            NULL|              False|             u'casual'|                          NULL|                    True|                        False|                          1|                       False|                       False|                   True|        NULL|                     True|    u'no'|
# |MUTTqe8uqyMdBl186...|            Tuna Bar|         205 Race St|  Philadelphia|   PA|      19106|    39.953949|   -75.1432262|  4.0|         245|      1|{RestaurantsReser...|Sushi Bars, Resta...|{Tuesday -> 13:30...|                 NULL|            NULL|  'full_bar'|{'touristy': Fals...|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{u'valet': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|           False|          NULL|               NULL|           False|{'dessert': True,...|                  NULL|          True|     False|      NULL|     u'average'|            NULL|               True|              'casual'|                          NULL|                    True|                         True|                          2|                        True|                        True|                   True|        NULL|                     True|   'free'|
# |rBmpy_Y1UbBx8ggHl...|Arizona Truck Out...|     625 N Stone Ave|        Tucson|   AZ|      85705|   32.2298719|  -110.9723419|  4.5|          10|      1|{DriveThru -> Fal...|Automotive, Auto ...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                 False|       NULL|          NULL|        NULL|                    NULL|            NULL|         False|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|  u'free'|
# |M0XSSHqrASOnhgbWD...|      Herb Import Co|        712 Adams St|   New Orleans|   LA|      70118|29.9414679565| -90.129952757|  4.0|           5|      1|{BusinessParking ...|Vape Shops, Tobac...|{Monday -> 10:0-1...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |8wGISYjYkE2tSqn3c...|    Nifty Car Rental|     1241 Airline Dr|        Kenner|   LA|      70062|    29.981183|   -90.2540123|  3.5|          14|      1|                NULL|Automotive, Car R...|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|
# |ROeacJQwBeh05Rqg7...|                 BAP|       1224 South St|  Philadelphia|   PA|      19147|    39.943223|    -75.162568|  4.5|         205|      1|{NoiseLevel -> u'...| Korean, Restaurants|{Monday -> 11:30-...|                 NULL|            NULL|     u'none'|{'touristy': Fals...|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|{'dessert': False...|                  NULL|          NULL|      True|      NULL|       u'quiet'|            NULL|               None|             u'casual'|                          NULL|                    None|                        False|                          1|                       False|                        True|                   True|        NULL|                     NULL|    u'no'|
# +--------------------+--------------------+--------------------+--------------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+--------------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+--------------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+
# only showing top 20 rows

# %%
def process_business_data(df):
    # Extract and parse JSON structured attributes
    df_with_parsed = df.withColumn(
        "business_parking_dict", 
        from_json(
            col("attributes").getItem("BusinessParking"),
            MapType(StringType(), BooleanType())
        )
    ).withColumn(
        "ambience_dict", 
        from_json(
            col("attributes").getItem("Ambience"),
            MapType(StringType(), BooleanType())
        )
    ).withColumn(
        "good_for_meal_dict", 
        from_json(
            col("attributes").getItem("GoodForMeal"),
            MapType(StringType(), BooleanType())
        )
    )

    # Extract specific values from these complex attributes
    df_with_parsed = df_with_parsed \
        .withColumn("garage_parking", col("business_parking_dict").getItem("garage")) \
        .withColumn("street_parking", col("business_parking_dict").getItem("street")) \
        .withColumn("lot_parking", col("business_parking_dict").getItem("lot")) \
        .withColumn("valet_parking", col("business_parking_dict").getItem("valet")) \
        .withColumn("is_romantic", col("ambience_dict").getItem("romantic")) \
        .withColumn("is_intimate", col("ambience_dict").getItem("intimate")) \
        .withColumn("is_classy", col("ambience_dict").getItem("classy")) \
        .withColumn("is_hipster", col("ambience_dict").getItem("hipster")) \
        .withColumn("good_for_dinner", col("good_for_meal_dict").getItem("dinner")) \
        .withColumn("good_for_lunch", col("good_for_meal_dict").getItem("lunch")) \
        .withColumn("good_for_breakfast", col("good_for_meal_dict").getItem("breakfast"))

    return df_with_parsed

df = process_business_data(df)
df.show(5)

# %%
hours_list = [
    "Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"
]

# Function to extract attribute values
def extract_hours(df, hours_list):
    # Create a copy of the original dataframe
    result_df = df
    
    # Extract each attribute as a separate column
    for hrs in hours_list:
        result_df = result_df.withColumn(
            f"hrs_{hrs}", 
            when(col("hours").getItem(hrs).isNotNull(), col("hours").getItem(hrs))
            .otherwise(lit(None))
        )
    
    return result_df

# Apply the extraction
df = extract_hours(df, hours_list)

# Show the result with some of the extracted columns
df.show(20)
# Out:
# +--------------------+--------------------+--------------------+--------------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+--------------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+--------------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+-----------+-----------+-------------+------------+-----------+------------+----------+
# |         business_id|                name|             address|          city|state|postal_code|     latitude|     longitude|stars|review_count|is_open|          attributes|          categories|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|       attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|    attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi| hrs_Monday|hrs_Tuesday|hrs_Wednesday|hrs_Thursday| hrs_Friday|hrs_Saturday|hrs_Sunday|
# +--------------------+--------------------+--------------------+--------------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+--------------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+--------------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+-----------+-----------+-------------+------------+-----------+------------+----------+
# |Pns2l4eNsfO8kk83d...|Abby Rappoport, L...|1616 Chapala St, ...| Santa Barbara|   CA|      93101|   34.4266787|  -119.7111968|  5.0|           7|      0|{ByAppointmentOnl...|Doctors, Traditio...|                NULL|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  True|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|       NULL|       NULL|         NULL|        NULL|       NULL|        NULL|      NULL|
# |mpf3x-BjTdTEA3yCZ...|       The UPS Store|87 Grasso Plaza S...|        Affton|   MO|      63123|    38.551126|    -90.335695|  3.0|          15|      1|{BusinessAcceptsC...|Shipping Centers,...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|    0:0-0:0|  8:0-18:30|    8:0-18:30|   8:0-18:30|  8:0-18:30|    8:0-14:0|      NULL|
# |tUFrWirKiKi_TAnsV...|              Target|5255 E Broadway Blvd|        Tucson|   AZ|      85711|    32.223236|   -110.880452|  3.5|          22|      0|{BikeParking -> T...|Department Stores...|{Monday -> 8:0-22...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                 False|      False|         False|        NULL|                    NULL|           False|          NULL|               NULL|            NULL|                NULL|                  NULL|         False|     False|      NULL|           NULL|            NULL|              False|                  NULL|                          NULL|                   False|                         NULL|                          2|                       False|                        NULL|                  False|        NULL|                     True|    u'no'|   8:0-22:0|   8:0-22:0|     8:0-22:0|    8:0-22:0|   8:0-23:0|    8:0-23:0|  8:0-22:0|
# |MTSW4McQd7CbVtyjq...|  St Honore Pastries|         935 Race St|  Philadelphia|   PA|      19107|   39.9555052|   -75.1555641|  4.0|          80|      1|{RestaurantsDeliv...|Restaurants, Food...|{Monday -> 7:0-20...|                 NULL|            NULL|     u'none'|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                          False|{'garage': False,...|                 False|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|              False|                  NULL|                          NULL|                   False|                         NULL|                          1|                        NULL|                        NULL|                   True|        NULL|                     NULL|  u'free'|   7:0-20:0|   7:0-20:0|     7:0-20:0|    7:0-20:0|   7:0-21:0|    7:0-21:0|  7:0-21:0|
# |mWMc6_wTdE0EUBKIG...|Perkiomen Valley ...|       101 Walnut St|    Green Lane|   PA|      18054|   40.3381827|   -75.4716585|  4.5|          13|      1|{BusinessAcceptsC...|Brewpubs, Breweri...|{Wednesday -> 14:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': None, ...|                  NULL|      False|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   True|        NULL|                     True|     NULL|       NULL|       NULL|    14:0-22:0|   16:0-22:0|  12:0-22:0|   12:0-22:0| 12:0-18:0|
# |CF33F8-E6oudUQ46H...|      Sonic Drive-In|       615 S Main St|  Ashland City|   TN|      37015|    36.269593|    -87.058943|  2.0|           6|      1|{BusinessParking ...|Burgers, Fast Foo...|{Monday -> 0:0-0:...|                 NULL|            NULL|     u'none'|                None|     NULL|            NULL|           NULL|           False|                       NULL|                           True|                None|                 False|      False|         False|        NULL|                    NULL|           False|          True|               NULL|            True|                NULL|                  NULL|         False|      True|      NULL|           NULL|            NULL|               True|             u'casual'|                          NULL|                    True|                         True|                          1|                       False|                       False|                   True|        NULL|                     True|    u'no'|    0:0-0:0|   6:0-22:0|     6:0-22:0|    6:0-22:0|    9:0-0:0|    9:0-22:0|  8:0-22:0|
# |n_0UpQx1hsNbnPUSl...|     Famous Footwear|8522 Eager Road, ...|     Brentwood|   MO|      63144|    38.627695|    -90.340465|  2.5|          13|      1|{BusinessAcceptsC...|Sporting Goods, F...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|    0:0-0:0|  10:0-18:0|    10:0-18:0|   10:0-18:0|  10:0-18:0|   10:0-18:0| 12:0-18:0|
# |qkRM_2X51Yqxk3btl...|      Temple Beth-El|  400 Pasadena Ave S|St. Petersburg|   FL|      33707|     27.76659|    -82.732983|  3.5|           5|      1|                NULL|Synagogues, Relig...|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|   9:0-17:0|   9:0-17:0|     9:0-17:0|    9:0-17:0|   9:0-17:0|        NULL|      NULL|
# |k0hlBqXX-Bt0vf1op...|Tsevi's Pub And G...|   8025 Mackenzie Rd|        Affton|   MO|      63123|   38.5651648|   -90.3210868|  3.0|          19|      0|{Caters -> True, ...|Pubs, Restaurants...|                NULL|                 NULL|            NULL| u'full_bar'|{'romantic': Fals...|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{'garage': False,...|                  NULL|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|                NULL|                  NULL|          NULL|      True|      NULL|     u'average'|            NULL|               True|             u'casual'|                          NULL|                   False|                         True|                          1|                       False|                        NULL|                   True|        NULL|                     NULL|  u'free'|       NULL|       NULL|         NULL|        NULL|       NULL|        NULL|      NULL|
# |bBDDEgkFA1Otx9Lfe...|      Sonic Drive-In| 2312 Dickerson Pike|     Nashville|   TN|      37207|   36.2081024|   -86.7681696|  1.5|          10|      1|{RestaurantsAttir...|Ice Cream & Froze...|{Monday -> 0:0-0:...|                 NULL|            NULL|     u'none'|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{'garage': False,...|                 False|      False|         False|        NULL|                    NULL|           False|          True|               NULL|            True|                NULL|                  NULL|         False|      True|      NULL|           NULL|            NULL|               True|              'casual'|                          NULL|                    True|                        False|                          1|                       False|                       False|                   True|        NULL|                     True|    u'no'|    0:0-0:0|   6:0-21:0|     6:0-21:0|    6:0-16:0|   6:0-16:0|    6:0-17:0|  6:0-21:0|
# |UJsufbvfyfONHeWdv...|           Marshalls|21705 Village Lak...| Land O' Lakes|   FL|      34639|28.1904587953|-82.4573802199|  3.5|           6|      1|{RestaurantsPrice...|Department Stores...|{Monday -> 9:30-2...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 9:30-21:30| 9:30-21:30|   9:30-21:30|  9:30-21:30| 9:30-21:30|  9:30-21:30| 10:0-20:0|
# |eEOYSgkmpB90uNA7l...|Vietnamese Food T...|                    |     Tampa Bay|   FL|      33602|   27.9552692|   -82.4563199|  4.0|          10|      1|{Alcohol -> 'none...|Vietnamese, Food,...|{Monday -> 11:0-1...|                 NULL|            NULL|      'none'|{'touristy': Fals...|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|{'dessert': False...|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               None|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                       False|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  11:0-14:0|  11:0-14:0|    11:0-14:0|   11:0-14:0|  11:0-14:0|    5:0-10:0| 15:0-18:0|
# |il_Ro8jwPlHresjw9...|             Denny's|        8901 US 31 S|  Indianapolis|   IN|      46227|39.6371332838| -86.127217412|  2.5|          28|      1|{RestaurantsReser...|American (Traditi...|{Monday -> 6:0-22...|                 NULL|            NULL|      'none'|{'touristy': None...|     NULL|            NULL|           NULL|           False|                       NULL|                           True|{'garage': None, ...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|{'dessert': False...|                  NULL|          NULL|      True|      NULL|           NULL|            NULL|              False|              'casual'|                          NULL|                    True|                         True|                          1|                       False|                        NULL|                   True|        NULL|                     NULL|    u'no'|   6:0-22:0|   6:0-22:0|     6:0-22:0|    6:0-22:0|   6:0-22:0|    6:0-22:0|  6:0-22:0|
# |jaxMSoInw8Poo3XeM...|        Adams Dental|   15 N Missouri Ave|    Clearwater|   FL|      33755|    27.966235|    -82.787412|  5.0|          10|      1|{ByAppointmentOnl...|General Dentistry...|{Monday -> 7:30-1...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  True|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 7:30-15:30| 7:30-15:30|   7:30-15:30|  7:30-15:30|       NULL|        NULL|      NULL|
# |0bPLkL0QhhPO5kt1_...|Zio's Italian Market|       2575 E Bay Dr|         Largo|   FL|      33771|   27.9161159|   -82.7604608|  4.5|         100|      0|{OutdoorSeating -...|Food, Delis, Ital...|{Monday -> 10:0-1...|                 NULL|            NULL|     u'none'|{'romantic': Fals...|     NULL|            NULL|           NULL|            True|                      False|                           True|{'garage': False,...|                  NULL|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|{'dessert': False...|                  NULL|          NULL|      True|      NULL|     u'average'|            NULL|              False|             u'casual'|                          NULL|                    True|                        False|                          1|                       False|                       False|                   True|        NULL|                     True|    u'no'|  10:0-18:0|  10:0-20:0|    10:0-20:0|   10:0-20:0|  10:0-20:0|   10:0-20:0|      NULL|
# |MUTTqe8uqyMdBl186...|            Tuna Bar|         205 Race St|  Philadelphia|   PA|      19106|    39.953949|   -75.1432262|  4.0|         245|      1|{RestaurantsReser...|Sushi Bars, Resta...|{Tuesday -> 13:30...|                 NULL|            NULL|  'full_bar'|{'touristy': Fals...|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{u'valet': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|           False|          NULL|               NULL|           False|{'dessert': True,...|                  NULL|          True|     False|      NULL|     u'average'|            NULL|               True|              'casual'|                          NULL|                    True|                         True|                          2|                        True|                        True|                   True|        NULL|                     True|   'free'|       NULL| 13:30-22:0|   13:30-22:0|  13:30-22:0| 13:30-23:0|  13:30-23:0|13:30-22:0|
# |rBmpy_Y1UbBx8ggHl...|Arizona Truck Out...|     625 N Stone Ave|        Tucson|   AZ|      85705|   32.2298719|  -110.9723419|  4.5|          10|      1|{DriveThru -> Fal...|Automotive, Auto ...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                 False|       NULL|          NULL|        NULL|                    NULL|            NULL|         False|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|  u'free'|    0:0-0:0|   8:0-17:0|     8:0-17:0|    8:0-17:0|   8:0-17:0|    8:0-14:0|   0:0-0:0|
# |M0XSSHqrASOnhgbWD...|      Herb Import Co|        712 Adams St|   New Orleans|   LA|      70118|29.9414679565| -90.129952757|  4.0|           5|      1|{BusinessParking ...|Vape Shops, Tobac...|{Monday -> 10:0-1...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  10:0-19:0|  10:0-19:0|    10:0-19:0|   10:0-19:0|  10:0-19:0|   10:0-19:0| 10:0-19:0|
# |8wGISYjYkE2tSqn3c...|    Nifty Car Rental|     1241 Airline Dr|        Kenner|   LA|      70062|    29.981183|   -90.2540123|  3.5|          14|      1|                NULL|Automotive, Car R...|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|                NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|                NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|   8:0-17:0|   8:0-17:0|     8:0-17:0|    8:0-17:0|   8:0-17:0|    9:0-15:0|  9:0-12:0|
# |ROeacJQwBeh05Rqg7...|                 BAP|       1224 South St|  Philadelphia|   PA|      19147|    39.943223|    -75.162568|  4.5|         205|      1|{NoiseLevel -> u'...| Korean, Restaurants|{Monday -> 11:30-...|                 NULL|            NULL|     u'none'|{'touristy': Fals...|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                  NULL|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|{'dessert': False...|                  NULL|          NULL|      True|      NULL|       u'quiet'|            NULL|               None|             u'casual'|                          NULL|                    None|                        False|                          1|                       False|                        True|                   True|        NULL|                     NULL|    u'no'|11:30-20:30|11:30-20:30|  11:30-20:30| 11:30-20:30|11:30-20:30| 11:30-20:30|      NULL|
# +--------------------+--------------------+--------------------+--------------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+--------------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+--------------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+-----------+-----------+-------------+------------+-----------+------------+----------+
# only showing top 20 rows

# %%
def handle_missing_values(df):
    imputer = Imputer(
        inputCols=["stars", "review_count"],
        outputCols=["stars_imputed", "review_count_imputed"]
    ).setStrategy("median")
    
    #df = imputer.fit(df).transform(df)
    
    df = df.na.fill({
        "is_open": 0,
        "name": "Unknown",
        "city": "Unknown",
        "state": "Unknown",
        "categories": "Uncategorized"
    })
    return df

df = handle_missing_values(df)
df.show(5)
# Out:
# +--------------------+--------------------+--------------------+-------------+-----+-----------+----------+------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |         business_id|                name|             address|         city|state|postal_code|  latitude|   longitude|stars|review_count|is_open|          attributes|          categories|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi|hrs_Monday|hrs_Tuesday|hrs_Wednesday|hrs_Thursday|hrs_Friday|hrs_Saturday|hrs_Sunday|
# +--------------------+--------------------+--------------------+-------------+-----+-----------+----------+------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |Pns2l4eNsfO8kk83d...|Abby Rappoport, L...|1616 Chapala St, ...|Santa Barbara|   CA|      93101|34.4266787|-119.7111968|  5.0|           7|      0|{ByAppointmentOnl...|Doctors, Traditio...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  True|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |mpf3x-BjTdTEA3yCZ...|       The UPS Store|87 Grasso Plaza S...|       Affton|   MO|      63123| 38.551126|  -90.335695|  3.0|          15|      1|{BusinessAcceptsC...|Shipping Centers,...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|   0:0-0:0|  8:0-18:30|    8:0-18:30|   8:0-18:30| 8:0-18:30|    8:0-14:0|      NULL|
# |tUFrWirKiKi_TAnsV...|              Target|5255 E Broadway Blvd|       Tucson|   AZ|      85711| 32.223236| -110.880452|  3.5|          22|      0|{BikeParking -> T...|Department Stores...|{Monday -> 8:0-22...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': False,...|                 False|      False|         False|        NULL|                    NULL|           False|          NULL|               NULL|            NULL|            NULL|                  NULL|         False|     False|      NULL|           NULL|            NULL|              False|                  NULL|                          NULL|                   False|                         NULL|                          2|                       False|                        NULL|                  False|        NULL|                     True|    u'no'|  8:0-22:0|   8:0-22:0|     8:0-22:0|    8:0-22:0|  8:0-23:0|    8:0-23:0|  8:0-22:0|
# |MTSW4McQd7CbVtyjq...|  St Honore Pastries|         935 Race St| Philadelphia|   PA|      19107|39.9555052| -75.1555641|  4.0|          80|      1|{RestaurantsDeliv...|Restaurants, Food...|{Monday -> 7:0-20...|                 NULL|            NULL|     u'none'|         NULL|     NULL|            NULL|           NULL|            True|                       NULL|                          False|{'garage': False,...|                 False|       True|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|              False|                  NULL|                          NULL|                   False|                         NULL|                          1|                        NULL|                        NULL|                   True|        NULL|                     NULL|  u'free'|  7:0-20:0|   7:0-20:0|     7:0-20:0|    7:0-20:0|  7:0-21:0|    7:0-21:0|  7:0-21:0|
# |mWMc6_wTdE0EUBKIG...|Perkiomen Valley ...|       101 Walnut St|   Green Lane|   PA|      18054|40.3381827| -75.4716585|  4.5|          13|      1|{BusinessAcceptsC...|Brewpubs, Breweri...|{Wednesday -> 14:...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            True|                       NULL|                           True|{'garage': None, ...|                  NULL|      False|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            True|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   True|        NULL|                     True|     NULL|      NULL|       NULL|    14:0-22:0|   16:0-22:0| 12:0-22:0|   12:0-22:0| 12:0-18:0|
# +--------------------+--------------------+--------------------+-------------+-----+-----------+----------+------------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# only showing top 5 rows

# %%
def remove_duplicates(df):
    df = df.dropDuplicates()
    df = df.dropDuplicates(["business_id"])
    return df

df = df.dropDuplicates(subset=[col for col in df.columns if df.schema[col].dataType != MapType(StringType(), StringType())])
df.show(5)
# Out:
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |         business_id|                name|             address|    city|state|postal_code|  latitude|  longitude|stars|review_count|is_open|          attributes|          categories|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi|hrs_Monday|hrs_Tuesday|hrs_Wednesday|hrs_Thursday|hrs_Friday|hrs_Saturday|hrs_Sunday|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |QMQP8sS4pRKDJ14I3...|Reed's Appliance ...|    1477 Blue Jay Rd|Abington|   PA|      19001|40.1380921|-75.1392754|  3.5|          15|      1|{BusinessAcceptsC...|Local Services, A...|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                          False|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  9:0-17:0|   9:0-17:0|     9:0-17:0|    9:0-17:0|  9:0-17:0|        NULL|      NULL|
# |1r_fBI9boktmsW_oJ...|Delaware Valley P...|500 E Providence ...|   Aldan|   PA|      19018|39.9253837| -75.279396|  3.5|           8|      1|                NULL|Pool & Hot Tub Se...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |BAxyMeWfg1w_HEaTZ...|              Fringe|        124 Front St|   Alton|   IL|      62002|38.8895142|-90.1840468|  5.0|           5|      1|                NULL|Hair Salons, Beau...|{Tuesday -> 10:0-...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|  10:0-17:0|    12:0-21:0|   12:0-21:0| 10:0-15:0|        NULL|      NULL|
# |ODJo95zDmCCw-qple...|           Dwyer Oil|       152 S Main St|  Ambler|   PA|      19002|40.1518262|-75.2226668|  4.5|          12|      1|{BusinessAcceptsC...|Home Services, He...|{Monday -> 8:0-16...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-16:30|  8:0-16:30|    8:0-16:30|   8:0-16:30| 8:0-16:30|        NULL|      NULL|
# |jmINqGKH1IC9IbVx3...|GT Automotive Center|       161 S Main St|  Ambler|   PA|      19002|40.1512531|-75.2218799|  3.5|           5|      1|{BusinessAcceptsC...|Automotive, Auto ...|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-17:30|  8:0-17:30|    8:0-17:30|   8:0-17:30| 8:0-17:30|        NULL|      NULL|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# only showing top 5 rows

# %%
def standardize_data(df):
    return df \
        .withColumn("name", trim(lower(col("name")))) \
        .withColumn("city", trim(lower(col("city")))) \
        .withColumn("state", trim(upper(col("state")))) \
        .withColumn("categories", trim(lower(col("categories")))) \
        .withColumn("postal_code", regexp_replace("postal_code", "[^0-9]", ""))

df = standardize_data(df)
df.show(5)
# Out:
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |         business_id|                name|             address|    city|state|postal_code|  latitude|  longitude|stars|review_count|is_open|          attributes|          categories|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi|hrs_Monday|hrs_Tuesday|hrs_Wednesday|hrs_Thursday|hrs_Friday|hrs_Saturday|hrs_Sunday|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |QMQP8sS4pRKDJ14I3...|reed's appliance ...|    1477 Blue Jay Rd|abington|   PA|      19001|40.1380921|-75.1392754|  3.5|          15|      1|{BusinessAcceptsC...|local services, a...|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                          False|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  9:0-17:0|   9:0-17:0|     9:0-17:0|    9:0-17:0|  9:0-17:0|        NULL|      NULL|
# |1r_fBI9boktmsW_oJ...|delaware valley p...|500 E Providence ...|   aldan|   PA|      19018|39.9253837| -75.279396|  3.5|           8|      1|                NULL|pool & hot tub se...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |BAxyMeWfg1w_HEaTZ...|              fringe|        124 Front St|   alton|   IL|      62002|38.8895142|-90.1840468|  5.0|           5|      1|                NULL|hair salons, beau...|{Tuesday -> 10:0-...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|  10:0-17:0|    12:0-21:0|   12:0-21:0| 10:0-15:0|        NULL|      NULL|
# |ODJo95zDmCCw-qple...|           dwyer oil|       152 S Main St|  ambler|   PA|      19002|40.1518262|-75.2226668|  4.5|          12|      1|{BusinessAcceptsC...|home services, he...|{Monday -> 8:0-16...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-16:30|  8:0-16:30|    8:0-16:30|   8:0-16:30| 8:0-16:30|        NULL|      NULL|
# |jmINqGKH1IC9IbVx3...|gt automotive center|       161 S Main St|  ambler|   PA|      19002|40.1512531|-75.2218799|  3.5|           5|      1|{BusinessAcceptsC...|automotive, auto ...|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-17:30|  8:0-17:30|    8:0-17:30|   8:0-17:30| 8:0-17:30|        NULL|      NULL|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# only showing top 5 rows

# %%
def handle_outliers(df):
    stats = df.select([
        percentile_approx("stars", 0.25).alias("q1_stars"),
        percentile_approx("stars", 0.75).alias("q3_stars"),
        percentile_approx("review_count", 0.25).alias("q1_reviews"),
        percentile_approx("review_count", 0.75).alias("q3_reviews")
    ]).collect()[0]
    
    iqr_stars = stats["q3_stars"] - stats["q1_stars"]
    iqr_reviews = stats["q3_reviews"] - stats["q1_reviews"]
    
    return df.filter(
        (col("stars").between(
            stats["q1_stars"] - 1.5 * iqr_stars,
            stats["q3_stars"] + 1.5 * iqr_stars
        )) &
        (col("review_count").between(
            stats["q1_reviews"] - 1.5 * iqr_reviews,
            stats["q3_reviews"] + 1.5 * iqr_reviews
        ))
    )

df = handle_outliers(df)
df.show(5)
# Out:
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |         business_id|                name|             address|    city|state|postal_code|  latitude|  longitude|stars|review_count|is_open|          attributes|          categories|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi|hrs_Monday|hrs_Tuesday|hrs_Wednesday|hrs_Thursday|hrs_Friday|hrs_Saturday|hrs_Sunday|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |QMQP8sS4pRKDJ14I3...|reed's appliance ...|    1477 Blue Jay Rd|abington|   PA|      19001|40.1380921|-75.1392754|  3.5|          15|      1|{BusinessAcceptsC...|local services, a...|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                          False|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  9:0-17:0|   9:0-17:0|     9:0-17:0|    9:0-17:0|  9:0-17:0|        NULL|      NULL|
# |1r_fBI9boktmsW_oJ...|delaware valley p...|500 E Providence ...|   aldan|   PA|      19018|39.9253837| -75.279396|  3.5|           8|      1|                NULL|pool & hot tub se...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |BAxyMeWfg1w_HEaTZ...|              fringe|        124 Front St|   alton|   IL|      62002|38.8895142|-90.1840468|  5.0|           5|      1|                NULL|hair salons, beau...|{Tuesday -> 10:0-...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|  10:0-17:0|    12:0-21:0|   12:0-21:0| 10:0-15:0|        NULL|      NULL|
# |ODJo95zDmCCw-qple...|           dwyer oil|       152 S Main St|  ambler|   PA|      19002|40.1518262|-75.2226668|  4.5|          12|      1|{BusinessAcceptsC...|home services, he...|{Monday -> 8:0-16...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-16:30|  8:0-16:30|    8:0-16:30|   8:0-16:30| 8:0-16:30|        NULL|      NULL|
# |jmINqGKH1IC9IbVx3...|gt automotive center|       161 S Main St|  ambler|   PA|      19002|40.1512531|-75.2218799|  3.5|           5|      1|{BusinessAcceptsC...|automotive, auto ...|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-17:30|  8:0-17:30|    8:0-17:30|   8:0-17:30| 8:0-17:30|        NULL|      NULL|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# only showing top 5 rows

# %%
def feature_engineering(df):
    df = df.withColumn("categories_array", split(col("categories"), ","))
    
    df = df.withColumn("price_range",
        when(col("attributes.RestaurantsPriceRange2") == "1", "Low")
        .when(col("attributes.RestaurantsPriceRange2") == "2", "Medium")
        .when(col("attributes.RestaurantsPriceRange2") == "3", "High")
        .when(col("attributes.RestaurantsPriceRange2") == "4", "Very High")
        .otherwise("Unknown")
    )
    
    df = df.withColumn("business_status", 
        when(col("is_open") == 1, "Active")
        .otherwise("Closed")
    )
    
    df = df.withColumn("rating_category",
        when(col("stars") >= 4.5, "Excellent")
        .when(col("stars") >= 4.0, "Very Good")
        .when(col("stars") >= 3.5, "Good")
        .when(col("stars") >= 3.0, "Average")
        .otherwise("Poor")
    )
    return df

# %%
def validate_data(df):
    df = df.filter(
        (col("stars").between(1, 5)) &
        (col("latitude").between(-90, 90)) &
        (col("longitude").between(-180, 180)) &
        (col("review_count") >= 0)
    )
    
    df = df.filter(
        (length(col("business_id")) > 0) &
        (length(col("postal_code")) == 5)
    )
    return df

df = validate_data(df)
df.show(5)
# Out:
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |         business_id|                name|             address|    city|state|postal_code|  latitude|  longitude|stars|review_count|is_open|          attributes|          categories|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi|hrs_Monday|hrs_Tuesday|hrs_Wednesday|hrs_Thursday|hrs_Friday|hrs_Saturday|hrs_Sunday|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |QMQP8sS4pRKDJ14I3...|reed's appliance ...|    1477 Blue Jay Rd|abington|   PA|      19001|40.1380921|-75.1392754|  3.5|          15|      1|{BusinessAcceptsC...|local services, a...|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                          False|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  9:0-17:0|   9:0-17:0|     9:0-17:0|    9:0-17:0|  9:0-17:0|        NULL|      NULL|
# |1r_fBI9boktmsW_oJ...|delaware valley p...|500 E Providence ...|   aldan|   PA|      19018|39.9253837| -75.279396|  3.5|           8|      1|                NULL|pool & hot tub se...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |BAxyMeWfg1w_HEaTZ...|              fringe|        124 Front St|   alton|   IL|      62002|38.8895142|-90.1840468|  5.0|           5|      1|                NULL|hair salons, beau...|{Tuesday -> 10:0-...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|  10:0-17:0|    12:0-21:0|   12:0-21:0| 10:0-15:0|        NULL|      NULL|
# |ODJo95zDmCCw-qple...|           dwyer oil|       152 S Main St|  ambler|   PA|      19002|40.1518262|-75.2226668|  4.5|          12|      1|{BusinessAcceptsC...|home services, he...|{Monday -> 8:0-16...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-16:30|  8:0-16:30|    8:0-16:30|   8:0-16:30| 8:0-16:30|        NULL|      NULL|
# |jmINqGKH1IC9IbVx3...|gt automotive center|       161 S Main St|  ambler|   PA|      19002|40.1512531|-75.2218799|  3.5|           5|      1|{BusinessAcceptsC...|automotive, auto ...|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 8:0-17:30|  8:0-17:30|    8:0-17:30|   8:0-17:30| 8:0-17:30|        NULL|      NULL|
# +--------------------+--------------------+--------------------+--------+-----+-----------+----------+-----------+-----+------------+-------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# only showing top 5 rows

# %%
def quality_checks(df):
    null_counts = df.select([sum(col(c).isNull().cast("int")).alias(c) 
                           for c in df.columns])
    
    duplicate_count = df.count() - df.dropDuplicates().count()
    
    value_dist = df.select(
        mean("stars").alias("mean_stars"),
        stddev("stars").alias("stddev_stars"),
        mean("review_count").alias("mean_reviews"),
        stddev("review_count").alias("stddev_reviews")
    )
    
    print("Null Counts:")
    null_counts.show()
    print(f"\nDuplicate Count: {duplicate_count}")
    print("\nValue Distributions:")
    value_dist.show()
    return df

# Remove duplicate rows based on all columns except 'attributes' and 'hours'
df_deduplicated = df.dropDuplicates([col for col in df.columns if df.schema[col].dataType != MapType(StringType(), StringType())])

# # Apply quality checks on the deduplicated DataFrame
# df_checked = quality_checks(df_deduplicated.drop("attributes", "hours"))

# Reassign the result back to df
df = df_deduplicated

# %%
df.write.format("delta") \
    .option("mergeSchema", "true") \
    .mode("overwrite") \
    .partitionBy("state") \
    .save("D:/Project/delta_lake/silver/business")

# %%
# Read business data from delta lake
business_df = spark.read.format("delta").load("D:/Project/delta_lake/silver/business")

# %%
# Display first few rows
business_df.show()

# Get schema information
business_df.printSchema()
# Out:
# +--------------------+--------------------+--------------------+----------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+-------------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |         business_id|                name|             address|      city|state|postal_code|     latitude|     longitude|stars|review_count|is_open|          categories|stars_imputed|review_count_imputed|          attributes|               hours|attr_AcceptsInsurance|attr_AgesAllowed|attr_Alcohol|attr_Ambience|attr_BYOB|attr_BYOBCorkage|attr_BestNights|attr_BikeParking|attr_BusinessAcceptsBitcoin|attr_BusinessAcceptsCreditCards|attr_BusinessParking|attr_ByAppointmentOnly|attr_Caters|attr_CoatCheck|attr_Corkage|attr_DietaryRestrictions|attr_DogsAllowed|attr_DriveThru|attr_GoodForDancing|attr_GoodForKids|attr_GoodForMeal|attr_HairSpecializesIn|attr_HappyHour|attr_HasTV|attr_Music|attr_NoiseLevel|attr_Open24Hours|attr_OutdoorSeating|attr_RestaurantsAttire|attr_RestaurantsCounterService|attr_RestaurantsDelivery|attr_RestaurantsGoodForGroups|attr_RestaurantsPriceRange2|attr_RestaurantsReservations|attr_RestaurantsTableService|attr_RestaurantsTakeOut|attr_Smoking|attr_WheelchairAccessible|attr_WiFi|hrs_Monday|hrs_Tuesday|hrs_Wednesday|hrs_Thursday|hrs_Friday|hrs_Saturday|hrs_Sunday|
# +--------------------+--------------------+--------------------+----------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+-------------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# |47ls8ov8TpyuXcr4v...|rogers middle school|   7550 MacKenzie Rd|    affton|   MO|      63123|     38.57325|    -90.317218|  2.0|           5|      1|middle schools & ...|         NULL|                NULL|                NULL|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |fqn9R_1BXMDn1nA_5...|       k9 packleader|      1445 Becker Rd|    arnold|   MO|      63010|38.4378305088|-90.3854178933|  5.0|          13|      1|pet training, pet...|         NULL|                NULL|                NULL|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  9:0-17:0|   9:0-17:0|     9:0-17:0|    9:0-17:0|  9:0-17:0|        NULL|      NULL|
# |WUXB1obE1-TbgOIvE...|home decorators c...| 13913 Manchester Rd|   ballwin|   MO|      63011|   38.5983872|   -90.4880137|  3.0|           5|      0|furniture stores,...|         NULL|                NULL|{RestaurantsPrice...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |SVB0vvNS60UD8WACe...|suntrup kia west ...| 14116 Manchester Rd|   ballwin|   MO|      63011|   38.5935068|   -90.4952056|  3.5|          20|      0|car dealers, auto...|         NULL|                NULL|{BusinessAcceptsC...|{Monday -> 9:0-21...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  9:0-21:0|   9:0-18:0|     9:0-21:0|    9:0-18:0|  9:0-21:0|        NULL|      NULL|
# |-P0cVKNzgqsqBsKkw...|      lamar's donuts|2542 S Brentwood ...| brentwood|   MO|      63144|    38.615212|   -90.3488425|  4.5|           8|      0|coffee & tea, foo...|         NULL|                NULL|{BusinessParking ...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               True|                  NULL|                          NULL|                    NULL|                         NULL|                          1|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|    u'no'|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |USMsyqRmZVEqaHzEw...|   carstar bridgeton|11976 Natural Bri...| bridgeton|   MO|      63044|   38.7549593|   -90.4099042|  5.0|           5|      0|commercial truck ...|         NULL|                NULL|{BusinessAcceptsC...|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  8:0-17:0|   8:0-17:0|     8:0-17:0|    8:0-17:0|  8:0-17:0|        NULL|      NULL|
# |85UoulEqp8RxnGxrI...|homestead studio ...| 11252 Lone Eagle Dr| bridgeton|   MO|      63044|   38.7430421|   -90.3991403|  3.0|           5|      1|hotels & travel, ...|         NULL|                NULL|{WiFi -> u'free',...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          1|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|  u'free'|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |r6rrUBf1tyQqdugo9...|             motel 6|  3470 Hollenberg Dr| bridgeton|   MO|      63044|    38.758808|    -90.437974|  2.0|          13|      1|     hotels & travel|         NULL|                NULL|                NULL|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |j8D96yzH1rxd6TjYu...|            smokey's|12207A Natural Br...| bridgeton|   MO|      63044|   38.7558323|   -90.4195018|  3.5|           5|      0|barbeque, restaur...|         NULL|                NULL|{RestaurantsTakeO...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|              'casual'|                          NULL|                   False|                         NULL|                       NULL|                       False|                        NULL|                   True|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |4EMIHaUOHcqRAG_KJ...|  fairway automotive|      8750 Watson Rd| crestwood|   MO|      63119|    38.563635|    -90.363777|  5.0|           7|      1|tires, auto repai...|         NULL|                NULL|{BusinessAcceptsC...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|  u'free'|   0:0-0:0|  7:30-18:0|    7:30-18:0|   7:30-18:0| 7:30-18:0|        NULL|      NULL|
# |YMvKrVTXHeSPQswWq...|            primebar|17 West County Ce...| des peres|   MO|      63131|    38.601903|    -90.447466|  3.5|          10|      0|restaurants, amer...|         NULL|                NULL|{OutdoorSeating -...|                NULL|                 NULL|            NULL| u'full_bar'|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|{'garage': True, ...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|           False|            NULL|                  NULL|          True|      NULL|      NULL|           NULL|            NULL|               True|             u'casual'|                          NULL|                    NULL|                         True|                          2|                        True|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |6O7GhTOQzu9dxHNL0...|    dalton logistics|   4045 Lakefront Ct|earth city|   MO|      63045|   38.7652263|   -90.4673582|  2.0|           5|      1|home & garden, sh...|         NULL|                NULL|                NULL|{Monday -> 8:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  8:0-17:0|   8:0-17:0|     8:0-17:0|    8:0-17:0|  8:0-17:0|        NULL|      NULL|
# |EpcQdrEEAZtSErntI...| ups customer center|   13818 Rider Trl N|earth city|   MO|      63045|    38.777649|    -90.464927|  1.5|          33|      1|post offices, shi...|         NULL|                NULL|{BusinessAcceptsC...|{Monday -> 7:30-1...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL| 7:30-19:0|  7:30-19:0|    7:30-19:0|   7:30-19:0| 7:30-19:0|        NULL|      NULL|
# |IUuoGJIdShjuwxZMX...|    caveman cleaning|  114 Countryview Ln|    fenton|   MO|      63026|   38.4789835|   -90.4387987|  1.5|           8|      1|home services, ho...|         NULL|                NULL|{BusinessAcceptsC...|{Monday -> 9:0-17...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|  9:0-17:0|   9:0-17:0|     9:0-17:0|    9:0-17:0|  9:0-17:0|        NULL|      NULL|
# |4Ks_Ex6Luc5jbQsbk...|          super wing|  60 N Florissant Rd|  ferguson|   MO|      63135|   38.7464638|   -90.3053609|  3.0|          10|      1|comfort food, fas...|         NULL|                NULL|{BusinessParking ...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|{'garage': False,...|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |4mg9x-NKiFo9SDDJS...|cecil whittaker's...|123 Flower Valley...|florissant|   MO|      63033|    38.812133|   -90.2967518|  2.5|           5|      1|  restaurants, pizza|         NULL|                NULL|{RestaurantsDeliv...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    True|                         NULL|                       NULL|                       False|                        NULL|                   True|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |odK95zwpR8URjQ7Ar...|first christian c...|   2890 Patterson Rd|florissant|   MO|      63031|   38.8196251|   -90.3176446|  2.0|           7|      1|religious organiz...|         NULL|                NULL|                NULL|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |BQL2v6BaMQlDa8Hba...|baymont inn and s...|      5781 Campus Ct| hazelwood|   MO|      63042|   38.7762336|    -90.389328|  1.0|          19|      0|hotels & travel, ...|         NULL|                NULL|{RestaurantsPrice...|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                          2|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|   'free'|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# |kNJxayRdQzs0NcshY...|unitech pest and ...|7220 N Lindbergh ...| hazelwood|   MO|      63042|   38.7812656|   -90.3537728|  4.0|           5|      1|pest control, loc...|         NULL|                NULL|{BusinessAcceptsC...|{Monday -> 0:0-0:...|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                      False|                           True|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|   0:0-0:0|   8:0-17:0|     8:0-17:0|    8:0-17:0|  8:0-17:0|        NULL|      NULL|
# |tyoCkkkBnyOJpynzr...|    herrell's market|        1015 Main St|  imperial|   MO|      63052|   38.3691653|   -90.3773518|  4.5|           7|      1|       grocery, food|         NULL|                NULL|                NULL|                NULL|                 NULL|            NULL|        NULL|         NULL|     NULL|            NULL|           NULL|            NULL|                       NULL|                           NULL|                NULL|                  NULL|       NULL|          NULL|        NULL|                    NULL|            NULL|          NULL|               NULL|            NULL|            NULL|                  NULL|          NULL|      NULL|      NULL|           NULL|            NULL|               NULL|                  NULL|                          NULL|                    NULL|                         NULL|                       NULL|                        NULL|                        NULL|                   NULL|        NULL|                     NULL|     NULL|      NULL|       NULL|         NULL|        NULL|      NULL|        NULL|      NULL|
# +--------------------+--------------------+--------------------+----------+-----+-----------+-------------+--------------+-----+------------+-------+--------------------+-------------+--------------------+--------------------+--------------------+---------------------+----------------+------------+-------------+---------+----------------+---------------+----------------+---------------------------+-------------------------------+--------------------+----------------------+-----------+--------------+------------+------------------------+----------------+--------------+-------------------+----------------+----------------+----------------------+--------------+----------+----------+---------------+----------------+-------------------+----------------------+------------------------------+------------------------+-----------------------------+---------------------------+----------------------------+----------------------------+-----------------------+------------+-------------------------+---------+----------+-----------+-------------+------------+----------+------------+----------+
# only showing top 20 rows
#
# root
#  |-- business_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- address: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- review_count: integer (nullable = true)
#  |-- is_open: integer (nullable = true)
#  |-- categories: string (nullable = true)
#  |-- stars_imputed: double (nullable = true)
#  |-- review_count_imputed: integer (nullable = true)
#  |-- attributes: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#  |-- hours: map (nullable = true)
#  |    |-- key: string
#  |    |-- value: string (valueContainsNull = true)
#  |-- attr_AcceptsInsurance: string (nullable = true)
#  |-- attr_AgesAllowed: string (nullable = true)
#  |-- attr_Alcohol: string (nullable = true)
#  |-- attr_Ambience: string (nullable = true)
#  |-- attr_BYOB: string (nullable = true)
#  |-- attr_BYOBCorkage: string (nullable = true)
#  |-- attr_BestNights: string (nullable = true)
#  |-- attr_BikeParking: string (nullable = true)
#  |-- attr_BusinessAcceptsBitcoin: string (nullable = true)
#  |-- attr_BusinessAcceptsCreditCards: string (nullable = true)
#  |-- attr_BusinessParking: string (nullable = true)
#  |-- attr_ByAppointmentOnly: string (nullable = true)
#  |-- attr_Caters: string (nullable = true)
#  |-- attr_CoatCheck: string (nullable = true)
#  |-- attr_Corkage: string (nullable = true)
#  |-- attr_DietaryRestrictions: string (nullable = true)
#  |-- attr_DogsAllowed: string (nullable = true)
#  |-- attr_DriveThru: string (nullable = true)
#  |-- attr_GoodForDancing: string (nullable = true)
#  |-- attr_GoodForKids: string (nullable = true)
#  |-- attr_GoodForMeal: string (nullable = true)
#  |-- attr_HairSpecializesIn: string (nullable = true)
#  |-- attr_HappyHour: string (nullable = true)
#  |-- attr_HasTV: string (nullable = true)
#  |-- attr_Music: string (nullable = true)
#  |-- attr_NoiseLevel: string (nullable = true)
#  |-- attr_Open24Hours: string (nullable = true)
#  |-- attr_OutdoorSeating: string (nullable = true)
#  |-- attr_RestaurantsAttire: string (nullable = true)
#  |-- attr_RestaurantsCounterService: string (nullable = true)
#  |-- attr_RestaurantsDelivery: string (nullable = true)
#  |-- attr_RestaurantsGoodForGroups: string (nullable = true)
#  |-- attr_RestaurantsPriceRange2: string (nullable = true)
#  |-- attr_RestaurantsReservations: string (nullable = true)
#  |-- attr_RestaurantsTableService: string (nullable = true)
#  |-- attr_RestaurantsTakeOut: string (nullable = true)
#  |-- attr_Smoking: string (nullable = true)
#  |-- attr_WheelchairAccessible: string (nullable = true)
#  |-- attr_WiFi: string (nullable = true)
#  |-- hrs_Monday: string (nullable = true)
#  |-- hrs_Tuesday: string (nullable = true)
#  |-- hrs_Wednesday: string (nullable = true)
#  |-- hrs_Thursday: string (nullable = true)
#  |-- hrs_Friday: string (nullable = true)
#  |-- hrs_Saturday: string (nullable = true)
#  |-- hrs_Sunday: string (nullable = true)
