# %%
import json
import logging
from pathlib import Path
from datetime import datetime
from typing import List, Dict, Any, Optional

from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType, DoubleType, LongType, ShortType, ByteType, BinaryType, BooleanType, DateType, TimestampType, NullType, ArrayType, MapType
from pyspark.sql.functions import col, lit, current_timestamp

class YelpDataProcessor:
    def __init__(self, spark_config: Dict[str, str] = None):
        """
        Khởi tạo YelpDataProcessor với cấu hình Spark tùy chỉnh
        
        Args:
            spark_config: Dictionary chứa các cấu hình Spark
        """
        self.logger = self._setup_logging()
        self.spark = self._create_spark_session(spark_config)
        
    def _setup_logging(self) -> logging.Logger:
        """Cấu hình logging chi tiết hơn"""
        logging.basicConfig(
            level=logging.DEBUG,  # Thay đổi level thành DEBUG để có thêm thông tin
            format='%(asctime)s - %(name)s - %(levelname)s - %(message)s'
        )
        return logging.getLogger(__name__)

    def _create_spark_session(self, spark_config: Dict[str, str] = None) -> SparkSession:
        """
        Tạo SparkSession với cấu hình tùy chỉnh và logging
        """
        default_config = {
            "spark.sql.parquet.compression.codec": "snappy",
            "spark.sql.parquet.mergeSchema": "true",
            "spark.sql.files.maxPartitionBytes": "128MB",
            "spark.sql.shuffle.partitions": "10",  # Giảm số partition mặc định
            "spark.driver.memory": "2g",
            "spark.executor.memory": "2g"
        }
        
        builder = SparkSession.builder.appName("YelpDataProcessor")
        
        # Áp dụng cấu hình mặc định
        for key, value in default_config.items():
            builder = builder.config(key, value)
            
        # Ghi đè bằng cấu hình tùy chỉnh nếu có
        if spark_config:
            for key, value in spark_config.items():
                builder = builder.config(key, value)
                
        spark = builder.getOrCreate()
        
        # Log cấu hình Spark
        self.logger.info("Spark Configuration:")
        for item in spark.sparkContext.getConf().getAll():
            self.logger.info(f"{item[0]}: {item[1]}")
            
        return spark

    def verify_input_file(self, input_path: str) -> bool:
        """
        Kiểm tra file input tồn tại và có thể đọc được
        """
        try:
            path = Path(input_path)
            if not path.exists():
                self.logger.error(f"File không tồn tại: {input_path}")
                return False
                
            # Thử đọc vài dòng đầu
            with open(input_path, 'r', encoding='utf-8') as f:
                for i, _ in enumerate(f):
                    if i >= 5: break  # Chỉ đọc 5 dòng đầu
                    
            return True
        except Exception as e:
            self.logger.error(f"Lỗi khi kiểm tra file input: {str(e)}")
            return False

    def verify_output_path(self, output_path: str) -> bool:
        """
        Kiểm tra và tạo thư mục output
        """
        try:
            path = Path(output_path)
            # Tạo thư mục nếu chưa tồn tại
            path.mkdir(parents=True, exist_ok=True)
            
            # Kiểm tra quyền ghi
            test_file = path / "test_write.tmp"
            test_file.touch()
            test_file.unlink()
            
            return True
        except Exception as e:
            self.logger.error(f"Lỗi khi kiểm tra thư mục output: {str(e)}")
            return False

    def cleanup(self) -> None:
        """Dọn dẹp tài nguyên Spark"""
        try:
            self.spark.stop()
            self.logger.info("Đã dừng SparkSession")
        except Exception as e:
            self.logger.error(f"Lỗi khi dừng SparkSession: {str(e)}")
            
    def define_schema(self) -> Optional[StructType]:
        """
        Định nghĩa schema cho Yelp Business dataset.
        Returns None nếu không cần validate schema.
        """
        return None
    def process_json_to_parquet(
        self,
        input_path: str,
        output_path: str,
        partition_columns: List[str] = None
    ) -> None:
        """
        Xử lý file JSON Yelp và lưu thành Parquet với kiểm tra chi tiết
        """
        try:
            # Kiểm tra input/output
            if not self.verify_input_file(input_path):
                raise ValueError(f"Invalid input file: {input_path}")
            if not self.verify_output_path(output_path):
                raise ValueError(f"Invalid output path: {output_path}")
                
            self.logger.info(f"Bắt đầu xử lý file: {input_path}")
            
            # Đọc một phần nhỏ dữ liệu để kiểm tra
            test_df = self.spark.read.json(
                input_path,
                schema=self.define_schema(),
                samplingRatio=0.1  # Chỉ đọc 10% dữ liệu để test
            )
            
            self.logger.info(f"Schema của DataFrame:")
            test_df.printSchema()
            
            # Đọc toàn bộ dữ liệu
            df = self.spark.read.json(
                input_path,
                schema=self.define_schema(),
                multiLine=False
            )
            
            # Log số lượng partitions
            partition_count = df.rdd.getNumPartitions()
            self.logger.info(f"Số lượng partitions: {partition_count}")
            
            # Thêm metadata
            df = df.withColumn("ingestion_timestamp", current_timestamp())\
                   .withColumn("source_file", lit(input_path))\
                   .withColumn("batch_id", lit(datetime.now().strftime("%Y%m%d_%H%M%S")))
            
            # Kiểm tra dữ liệu trước khi lưu
            row_count = df.count()
            self.logger.info(f"Số lượng records: {row_count}")
            
            if row_count == 0:
                raise ValueError("Không có dữ liệu để xử lý")
            
            # Lưu từng partition riêng biệt để dễ debug
            if partition_columns:
                # Kiểm tra partition columns tồn tại
                missing_cols = [col for col in partition_columns if col not in df.columns]
                if missing_cols:
                    raise ValueError(f"Các cột partition không tồn tại: {missing_cols}")
                
                self.logger.info(f"Partition theo các cột: {partition_columns}")
                
                writer = df.write\
                    .mode("append")\
                    .format("parquet")\
                    .option("compression", "snappy")\
                    .partitionBy(partition_columns)
            else:
                writer = df.write\
                    .mode("append")\
                    .format("parquet")\
                    .option("compression", "snappy")
            
            # Thử lưu một phần nhỏ dữ liệu trước
            test_output = f"{output_path}_test"
            test_df.write\
                .mode("overwrite")\
                .format("parquet")\
                .save(test_output)
                
            self.logger.info("Test write thành công, tiến hành lưu toàn bộ dữ liệu")
            
            # Lưu toàn bộ dữ liệu
            writer.save(output_path)
            
            # Kiểm tra kết quả
            result_df = self.spark.read.parquet(output_path)
            result_count = result_df.count()
            
            if result_count != row_count:
                raise ValueError(f"Số lượng records không khớp: {result_count} != {row_count}")
                
            self.logger.info(f"Đã xử lý và lưu thành công {result_count} records")
            
        except Exception as e:
            self.logger.error(f"Lỗi chi tiết khi xử lý dữ liệu: {str(e)}", exc_info=True)
            raise

def main():
    # Cấu hình Spark với ít memory hơn và ít partitions hơn
    spark_config = {
        "spark.driver.memory": "2g",
        "spark.executor.memory": "2g",
        "spark.sql.shuffle.partitions": "10",
        "spark.default.parallelism": "10"
    }
    
    processor = YelpDataProcessor(spark_config)
    
    try:
        input_path = "D:/Project/data/yelp_academic_dataset_business.json"
        output_path = "D:/Project/delta_lake/bronze/yelp_data/"
        
        # Thử không dùng partition trước
        processor.process_json_to_parquet(
            input_path=input_path,
            output_path=output_path
        )
        
    except Exception as e:
        processor.logger.error(f"Lỗi trong main: {str(e)}", exc_info=True)
    finally:
        processor.cleanup()

if __name__ == "__main__":
    main()
# Out:
# 2025-01-16 12:12:59,415 - py4j.java_gateway - DEBUG - GatewayClient.address is deprecated and will be removed in version 1.0. Use GatewayParameters instead.
# 2025-01-16 12:12:59,417 - py4j.clientserver - DEBUG - Command to send: A
# 1320099b229fb756689f639ea33f2f0765c7d89e376e0d856a9ba7f31a0d0d35
#
# 2025-01-16 12:12:59,432 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,434 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.SparkConf
# e
#
# 2025-01-16 12:12:59,437 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,438 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.api.java.*
# e
#
# 2025-01-16 12:12:59,439 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,439 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.api.python.*
# e
#
# 2025-01-16 12:12:59,440 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,441 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.ml.python.*
# e
#
# 2025-01-16 12:12:59,442 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,442 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.mllib.api.python.*
# e
#
# 2025-01-16 12:12:59,444 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,444 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.resource.*
# e
#
# 2025-01-16 12:12:59,445 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,446 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.sql.*
# e
#
# 2025-01-16 12:12:59,446 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,447 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.sql.api.python.*
# e
#
# 2025-01-16 12:12:59,447 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,448 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# org.apache.spark.sql.hive.*
# e
#
# 2025-01-16 12:12:59,448 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,449 - py4j.clientserver - DEBUG - Command to send: j
# i
# rj
# scala.Tuple2
# e
#
# 2025-01-16 12:12:59,449 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:12:59,450 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkConf
# rj
# e
#
# 2025-01-16 12:12:59,452 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.SparkConf
# 2025-01-16 12:12:59,453 - py4j.clientserver - DEBUG - Command to send: i
# org.apache.spark.SparkConf
# bTrue
# e
#
# 2025-01-16 12:12:59,460 - py4j.clientserver - DEBUG - Answer received: !yro0
# 2025-01-16 12:12:59,461 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.app.name
# sYelpDataProcessor
# e
#
# 2025-01-16 12:12:59,465 - py4j.clientserver - DEBUG - Answer received: !yro1
# 2025-01-16 12:12:59,466 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.sql.parquet.compression.codec
# ssnappy
# e
#
# 2025-01-16 12:12:59,466 - py4j.clientserver - DEBUG - Answer received: !yro2
# 2025-01-16 12:12:59,467 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.sql.parquet.mergeSchema
# strue
# e
#
# 2025-01-16 12:12:59,467 - py4j.clientserver - DEBUG - Answer received: !yro3
# 2025-01-16 12:12:59,467 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.sql.files.maxPartitionBytes
# s128MB
# e
#
# 2025-01-16 12:12:59,468 - py4j.clientserver - DEBUG - Answer received: !yro4
# 2025-01-16 12:12:59,469 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.sql.shuffle.partitions
# s10
# e
#
# 2025-01-16 12:12:59,471 - py4j.clientserver - DEBUG - Answer received: !yro5
# 2025-01-16 12:12:59,472 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.driver.memory
# s2g
# e
#
# 2025-01-16 12:12:59,473 - py4j.clientserver - DEBUG - Answer received: !yro6
# 2025-01-16 12:12:59,473 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.executor.memory
# s2g
# e
#
# 2025-01-16 12:12:59,474 - py4j.clientserver - DEBUG - Answer received: !yro7
# 2025-01-16 12:12:59,475 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.default.parallelism
# s10
# e
#
# 2025-01-16 12:12:59,476 - py4j.clientserver - DEBUG - Answer received: !yro8
# 2025-01-16 12:12:59,476 - py4j.clientserver - DEBUG - Command to send: c
# o0
# contains
# sspark.serializer.objectStreamReset
# e
#
# 2025-01-16 12:12:59,478 - py4j.clientserver - DEBUG - Answer received: !ybfalse
# 2025-01-16 12:12:59,478 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.serializer.objectStreamReset
# s100
# e
#
# 2025-01-16 12:12:59,479 - py4j.clientserver - DEBUG - Answer received: !yro9
# 2025-01-16 12:12:59,479 - py4j.clientserver - DEBUG - Command to send: c
# o0
# contains
# sspark.rdd.compress
# e
#
# 2025-01-16 12:12:59,479 - py4j.clientserver - DEBUG - Answer received: !ybfalse
# 2025-01-16 12:12:59,480 - py4j.clientserver - DEBUG - Command to send: c
# o0
# set
# sspark.rdd.compress
# sTrue
# e
#
# 2025-01-16 12:12:59,480 - py4j.clientserver - DEBUG - Answer received: !yro10
# 2025-01-16 12:12:59,481 - py4j.clientserver - DEBUG - Command to send: c
# o0
# contains
# sspark.master
# e
#
# 2025-01-16 12:12:59,481 - py4j.clientserver - DEBUG - Answer received: !ybtrue
# 2025-01-16 12:12:59,482 - py4j.clientserver - DEBUG - Command to send: c
# o0
# contains
# sspark.app.name
# e
#
# 2025-01-16 12:12:59,482 - py4j.clientserver - DEBUG - Answer received: !ybtrue
# 2025-01-16 12:12:59,483 - py4j.clientserver - DEBUG - Command to send: c
# o0
# contains
# sspark.master
# e
#
# 2025-01-16 12:12:59,483 - py4j.clientserver - DEBUG - Answer received: !ybtrue
# 2025-01-16 12:12:59,484 - py4j.clientserver - DEBUG - Command to send: c
# o0
# get
# sspark.master
# e
#
# 2025-01-16 12:12:59,485 - py4j.clientserver - DEBUG - Answer received: !yslocal[*]
# 2025-01-16 12:12:59,486 - py4j.clientserver - DEBUG - Command to send: c
# o0
# contains
# sspark.app.name
# e
#
# 2025-01-16 12:12:59,488 - py4j.clientserver - DEBUG - Answer received: !ybtrue
# 2025-01-16 12:12:59,489 - py4j.clientserver - DEBUG - Command to send: c
# o0
# get
# sspark.app.name
# e
#
# 2025-01-16 12:12:59,490 - py4j.clientserver - DEBUG - Answer received: !ysYelpDataProcessor
# 2025-01-16 12:12:59,491 - py4j.clientserver - DEBUG - Command to send: c
# o0
# contains
# sspark.home
# e
#
# 2025-01-16 12:12:59,492 - py4j.clientserver - DEBUG - Answer received: !ybfalse
# 2025-01-16 12:12:59,494 - py4j.clientserver - DEBUG - Command to send: c
# o0
# getAll
# e
#
# 2025-01-16 12:12:59,497 - py4j.clientserver - DEBUG - Answer received: !yto11
# 2025-01-16 12:12:59,497 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,498 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,498 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i0
# e
#
# 2025-01-16 12:12:59,499 - py4j.clientserver - DEBUG - Answer received: !yro12
# 2025-01-16 12:12:59,500 - py4j.clientserver - DEBUG - Command to send: c
# o12
# _1
# e
#
# 2025-01-16 12:12:59,501 - py4j.clientserver - DEBUG - Answer received: !ysspark.app.submitTime
# 2025-01-16 12:12:59,502 - py4j.clientserver - DEBUG - Command to send: c
# o12
# _2
# e
#
# 2025-01-16 12:12:59,504 - py4j.clientserver - DEBUG - Answer received: !ys1737004379345
# 2025-01-16 12:12:59,505 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,505 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,506 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i1
# e
#
# 2025-01-16 12:12:59,507 - py4j.clientserver - DEBUG - Answer received: !yro13
# 2025-01-16 12:12:59,508 - py4j.clientserver - DEBUG - Command to send: c
# o13
# _1
# e
#
# 2025-01-16 12:12:59,509 - py4j.clientserver - DEBUG - Answer received: !ysspark.executor.memory
# 2025-01-16 12:12:59,509 - py4j.clientserver - DEBUG - Command to send: c
# o13
# _2
# e
#
# 2025-01-16 12:12:59,510 - py4j.clientserver - DEBUG - Answer received: !ys2g
# 2025-01-16 12:12:59,510 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,511 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,511 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i2
# e
#
# 2025-01-16 12:12:59,512 - py4j.clientserver - DEBUG - Answer received: !yro14
# 2025-01-16 12:12:59,512 - py4j.clientserver - DEBUG - Command to send: c
# o14
# _1
# e
#
# 2025-01-16 12:12:59,513 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.parquet.mergeSchema
# 2025-01-16 12:12:59,513 - py4j.clientserver - DEBUG - Command to send: c
# o14
# _2
# e
#
# 2025-01-16 12:12:59,514 - py4j.clientserver - DEBUG - Answer received: !ystrue
# 2025-01-16 12:12:59,514 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,515 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,515 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i3
# e
#
# 2025-01-16 12:12:59,516 - py4j.clientserver - DEBUG - Answer received: !yro15
# 2025-01-16 12:12:59,516 - py4j.clientserver - DEBUG - Command to send: c
# o15
# _1
# e
#
# 2025-01-16 12:12:59,517 - py4j.clientserver - DEBUG - Answer received: !ysspark.app.name
# 2025-01-16 12:12:59,517 - py4j.clientserver - DEBUG - Command to send: c
# o15
# _2
# e
#
# 2025-01-16 12:12:59,517 - py4j.clientserver - DEBUG - Answer received: !ysYelpDataProcessor
# 2025-01-16 12:12:59,518 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,520 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,522 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i4
# e
#
# 2025-01-16 12:12:59,523 - py4j.clientserver - DEBUG - Answer received: !yro16
# 2025-01-16 12:12:59,523 - py4j.clientserver - DEBUG - Command to send: c
# o16
# _1
# e
#
# 2025-01-16 12:12:59,524 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.shuffle.partitions
# 2025-01-16 12:12:59,524 - py4j.clientserver - DEBUG - Command to send: c
# o16
# _2
# e
#
# 2025-01-16 12:12:59,525 - py4j.clientserver - DEBUG - Answer received: !ys10
# 2025-01-16 12:12:59,525 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,526 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,526 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i5
# e
#
# 2025-01-16 12:12:59,526 - py4j.clientserver - DEBUG - Answer received: !yro17
# 2025-01-16 12:12:59,528 - py4j.clientserver - DEBUG - Command to send: c
# o17
# _1
# e
#
# 2025-01-16 12:12:59,529 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.parquet.compression.codec
# 2025-01-16 12:12:59,529 - py4j.clientserver - DEBUG - Command to send: c
# o17
# _2
# e
#
# 2025-01-16 12:12:59,530 - py4j.clientserver - DEBUG - Answer received: !yssnappy
# 2025-01-16 12:12:59,530 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,531 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,532 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i6
# e
#
# 2025-01-16 12:12:59,532 - py4j.clientserver - DEBUG - Answer received: !yro18
# 2025-01-16 12:12:59,532 - py4j.clientserver - DEBUG - Command to send: c
# o18
# _1
# e
#
# 2025-01-16 12:12:59,533 - py4j.clientserver - DEBUG - Answer received: !ysspark.default.parallelism
# 2025-01-16 12:12:59,533 - py4j.clientserver - DEBUG - Command to send: c
# o18
# _2
# e
#
# 2025-01-16 12:12:59,534 - py4j.clientserver - DEBUG - Answer received: !ys10
# 2025-01-16 12:12:59,534 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,535 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,535 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i7
# e
#
# 2025-01-16 12:12:59,536 - py4j.clientserver - DEBUG - Answer received: !yro19
# 2025-01-16 12:12:59,537 - py4j.clientserver - DEBUG - Command to send: c
# o19
# _1
# e
#
# 2025-01-16 12:12:59,538 - py4j.clientserver - DEBUG - Answer received: !ysspark.rdd.compress
# 2025-01-16 12:12:59,539 - py4j.clientserver - DEBUG - Command to send: c
# o19
# _2
# e
#
# 2025-01-16 12:12:59,539 - py4j.clientserver - DEBUG - Answer received: !ysTrue
# 2025-01-16 12:12:59,540 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,540 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,541 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i8
# e
#
# 2025-01-16 12:12:59,542 - py4j.clientserver - DEBUG - Answer received: !yro20
# 2025-01-16 12:12:59,542 - py4j.clientserver - DEBUG - Command to send: c
# o20
# _1
# e
#
# 2025-01-16 12:12:59,543 - py4j.clientserver - DEBUG - Answer received: !ysspark.driver.memory
# 2025-01-16 12:12:59,543 - py4j.clientserver - DEBUG - Command to send: c
# o20
# _2
# e
#
# 2025-01-16 12:12:59,544 - py4j.clientserver - DEBUG - Answer received: !ys2g
# 2025-01-16 12:12:59,544 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,545 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,545 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i9
# e
#
# 2025-01-16 12:12:59,546 - py4j.clientserver - DEBUG - Answer received: !yro21
# 2025-01-16 12:12:59,546 - py4j.clientserver - DEBUG - Command to send: c
# o21
# _1
# e
#
# 2025-01-16 12:12:59,547 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.files.maxPartitionBytes
# 2025-01-16 12:12:59,547 - py4j.clientserver - DEBUG - Command to send: c
# o21
# _2
# e
#
# 2025-01-16 12:12:59,548 - py4j.clientserver - DEBUG - Answer received: !ys128MB
# 2025-01-16 12:12:59,548 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,549 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,549 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i10
# e
#
# 2025-01-16 12:12:59,550 - py4j.clientserver - DEBUG - Answer received: !yro22
# 2025-01-16 12:12:59,550 - py4j.clientserver - DEBUG - Command to send: c
# o22
# _1
# e
#
# 2025-01-16 12:12:59,551 - py4j.clientserver - DEBUG - Answer received: !ysspark.serializer.objectStreamReset
# 2025-01-16 12:12:59,552 - py4j.clientserver - DEBUG - Command to send: c
# o22
# _2
# e
#
# 2025-01-16 12:12:59,553 - py4j.clientserver - DEBUG - Answer received: !ys100
# 2025-01-16 12:12:59,553 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,554 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,555 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i11
# e
#
# 2025-01-16 12:12:59,555 - py4j.clientserver - DEBUG - Answer received: !yro23
# 2025-01-16 12:12:59,556 - py4j.clientserver - DEBUG - Command to send: c
# o23
# _1
# e
#
# 2025-01-16 12:12:59,556 - py4j.clientserver - DEBUG - Answer received: !ysspark.master
# 2025-01-16 12:12:59,557 - py4j.clientserver - DEBUG - Command to send: c
# o23
# _2
# e
#
# 2025-01-16 12:12:59,557 - py4j.clientserver - DEBUG - Answer received: !yslocal[*]
# 2025-01-16 12:12:59,558 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,559 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,559 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i12
# e
#
# 2025-01-16 12:12:59,560 - py4j.clientserver - DEBUG - Answer received: !yro24
# 2025-01-16 12:12:59,561 - py4j.clientserver - DEBUG - Command to send: c
# o24
# _1
# e
#
# 2025-01-16 12:12:59,561 - py4j.clientserver - DEBUG - Answer received: !ysspark.submit.pyFiles
# 2025-01-16 12:12:59,562 - py4j.clientserver - DEBUG - Command to send: c
# o24
# _2
# e
#
# 2025-01-16 12:12:59,562 - py4j.clientserver - DEBUG - Answer received: !ys
# 2025-01-16 12:12:59,563 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,563 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,564 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i13
# e
#
# 2025-01-16 12:12:59,564 - py4j.clientserver - DEBUG - Answer received: !yro25
# 2025-01-16 12:12:59,565 - py4j.clientserver - DEBUG - Command to send: c
# o25
# _1
# e
#
# 2025-01-16 12:12:59,565 - py4j.clientserver - DEBUG - Answer received: !ysspark.submit.deployMode
# 2025-01-16 12:12:59,565 - py4j.clientserver - DEBUG - Command to send: c
# o25
# _2
# e
#
# 2025-01-16 12:12:59,567 - py4j.clientserver - DEBUG - Answer received: !ysclient
# 2025-01-16 12:12:59,567 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,568 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,568 - py4j.clientserver - DEBUG - Command to send: a
# g
# o11
# i14
# e
#
# 2025-01-16 12:12:59,568 - py4j.clientserver - DEBUG - Answer received: !yro26
# 2025-01-16 12:12:59,569 - py4j.clientserver - DEBUG - Command to send: c
# o26
# _1
# e
#
# 2025-01-16 12:12:59,570 - py4j.clientserver - DEBUG - Answer received: !ysspark.ui.showConsoleProgress
# 2025-01-16 12:12:59,571 - py4j.clientserver - DEBUG - Command to send: c
# o26
# _2
# e
#
# 2025-01-16 12:12:59,571 - py4j.clientserver - DEBUG - Answer received: !ystrue
# 2025-01-16 12:12:59,572 - py4j.clientserver - DEBUG - Command to send: a
# e
# o11
# e
#
# 2025-01-16 12:12:59,573 - py4j.clientserver - DEBUG - Answer received: !yi15
# 2025-01-16 12:12:59,574 - py4j.clientserver - DEBUG - Command to send: r
# u
# JavaSparkContext
# rj
# e
#
# 2025-01-16 12:12:59,586 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.api.java.JavaSparkContext
# 2025-01-16 12:12:59,588 - py4j.clientserver - DEBUG - Command to send: i
# org.apache.spark.api.java.JavaSparkContext
# ro0
# e
#
# 2025-01-16 12:13:00,416 - py4j.clientserver - DEBUG - Command to send: A
# 1320099b229fb756689f639ea33f2f0765c7d89e376e0d856a9ba7f31a0d0d35
#
# 2025-01-16 12:13:00,418 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,419 - py4j.clientserver - DEBUG - Command to send: m
# d
# o1
# e
#
# 2025-01-16 12:13:00,420 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,421 - py4j.clientserver - DEBUG - Command to send: m
# d
# o2
# e
#
# 2025-01-16 12:13:00,421 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,422 - py4j.clientserver - DEBUG - Command to send: m
# d
# o3
# e
#
# 2025-01-16 12:13:00,423 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,424 - py4j.clientserver - DEBUG - Command to send: m
# d
# o4
# e
#
# 2025-01-16 12:13:00,425 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,425 - py4j.clientserver - DEBUG - Command to send: m
# d
# o5
# e
#
# 2025-01-16 12:13:00,426 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,426 - py4j.clientserver - DEBUG - Command to send: m
# d
# o6
# e
#
# 2025-01-16 12:13:00,427 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,427 - py4j.clientserver - DEBUG - Command to send: m
# d
# o7
# e
#
# 2025-01-16 12:13:00,427 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,429 - py4j.clientserver - DEBUG - Command to send: m
# d
# o8
# e
#
# 2025-01-16 12:13:00,429 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,430 - py4j.clientserver - DEBUG - Command to send: m
# d
# o9
# e
#
# 2025-01-16 12:13:00,430 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,431 - py4j.clientserver - DEBUG - Command to send: m
# d
# o10
# e
#
# 2025-01-16 12:13:00,432 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,432 - py4j.clientserver - DEBUG - Command to send: m
# d
# o12
# e
#
# 2025-01-16 12:13:00,433 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,434 - py4j.clientserver - DEBUG - Command to send: m
# d
# o13
# e
#
# 2025-01-16 12:13:00,434 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,435 - py4j.clientserver - DEBUG - Command to send: m
# d
# o14
# e
#
# 2025-01-16 12:13:00,436 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,436 - py4j.clientserver - DEBUG - Command to send: m
# d
# o16
# e
#
# 2025-01-16 12:13:00,437 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,438 - py4j.clientserver - DEBUG - Command to send: m
# d
# o17
# e
#
# 2025-01-16 12:13:00,439 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,440 - py4j.clientserver - DEBUG - Command to send: m
# d
# o18
# e
#
# 2025-01-16 12:13:00,440 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,441 - py4j.clientserver - DEBUG - Command to send: m
# d
# o19
# e
#
# 2025-01-16 12:13:00,442 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,443 - py4j.clientserver - DEBUG - Command to send: m
# d
# o20
# e
#
# 2025-01-16 12:13:00,443 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,444 - py4j.clientserver - DEBUG - Command to send: m
# d
# o21
# e
#
# 2025-01-16 12:13:00,445 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,445 - py4j.clientserver - DEBUG - Command to send: m
# d
# o22
# e
#
# 2025-01-16 12:13:00,446 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,446 - py4j.clientserver - DEBUG - Command to send: m
# d
# o23
# e
#
# 2025-01-16 12:13:00,447 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,448 - py4j.clientserver - DEBUG - Command to send: m
# d
# o24
# e
#
# 2025-01-16 12:13:00,448 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:00,449 - py4j.clientserver - DEBUG - Command to send: m
# d
# o11
# e
#
# 2025-01-16 12:13:00,450 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,110 - py4j.clientserver - DEBUG - Answer received: !yro27
# 2025-01-16 12:13:01,110 - py4j.clientserver - DEBUG - Command to send: c
# o27
# sc
# e
#
# 2025-01-16 12:13:01,114 - py4j.clientserver - DEBUG - Answer received: !yro28
# 2025-01-16 12:13:01,115 - py4j.clientserver - DEBUG - Command to send: c
# o28
# conf
# e
#
# 2025-01-16 12:13:01,126 - py4j.clientserver - DEBUG - Answer received: !yro29
# 2025-01-16 12:13:01,130 - py4j.clientserver - DEBUG - Command to send: r
# u
# PythonAccumulatorV2
# rj
# e
#
# 2025-01-16 12:13:01,132 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonAccumulatorV2
# 2025-01-16 12:13:01,133 - py4j.clientserver - DEBUG - Command to send: i
# org.apache.spark.api.python.PythonAccumulatorV2
# s127.0.0.1
# i49238
# s1320099b229fb756689f639ea33f2f0765c7d89e376e0d856a9ba7f31a0d0d35
# e
#
# 2025-01-16 12:13:01,134 - py4j.clientserver - DEBUG - Answer received: !yro30
# 2025-01-16 12:13:01,134 - py4j.clientserver - DEBUG - Command to send: c
# o27
# sc
# e
#
# 2025-01-16 12:13:01,135 - py4j.clientserver - DEBUG - Answer received: !yro31
# 2025-01-16 12:13:01,136 - py4j.clientserver - DEBUG - Command to send: c
# o31
# register
# ro30
# e
#
# 2025-01-16 12:13:01,140 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,141 - py4j.clientserver - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 2025-01-16 12:13:01,142 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 2025-01-16 12:13:01,143 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# isEncryptionEnabled
# e
#
# 2025-01-16 12:13:01,144 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,144 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# isEncryptionEnabled
# ro27
# e
#
# 2025-01-16 12:13:01,147 - py4j.clientserver - DEBUG - Answer received: !ybfalse
# 2025-01-16 12:13:01,148 - py4j.clientserver - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 2025-01-16 12:13:01,149 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 2025-01-16 12:13:01,149 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getPythonAuthSocketTimeout
# e
#
# 2025-01-16 12:13:01,150 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,150 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getPythonAuthSocketTimeout
# ro27
# e
#
# 2025-01-16 12:13:01,151 - py4j.clientserver - DEBUG - Answer received: !yL15
# 2025-01-16 12:13:01,151 - py4j.clientserver - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 2025-01-16 12:13:01,153 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 2025-01-16 12:13:01,154 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getSparkBufferSize
# e
#
# 2025-01-16 12:13:01,155 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,155 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getSparkBufferSize
# ro27
# e
#
# 2025-01-16 12:13:01,156 - py4j.clientserver - DEBUG - Answer received: !yi65536
# 2025-01-16 12:13:01,157 - py4j.clientserver - DEBUG - Command to send: r
# u
# org
# rj
# e
#
# 2025-01-16 12:13:01,159 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,159 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache
# rj
# e
#
# 2025-01-16 12:13:01,160 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,161 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark
# rj
# e
#
# 2025-01-16 12:13:01,162 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,162 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark.SparkFiles
# rj
# e
#
# 2025-01-16 12:13:01,163 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.SparkFiles
# 2025-01-16 12:13:01,163 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.SparkFiles
# getRootDirectory
# e
#
# 2025-01-16 12:13:01,164 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,164 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.SparkFiles
# getRootDirectory
# e
#
# 2025-01-16 12:13:01,166 - py4j.clientserver - DEBUG - Answer received: !ysC:\\Users\\trieu\\AppData\\Local\\Temp\\spark-b52c4ed4-e99c-40b7-b385-30a6d91daa27\\userFiles-b1ac2bd3-7657-40b4-97dd-53b3822b21bb
# 2025-01-16 12:13:01,166 - py4j.clientserver - DEBUG - Command to send: c
# o29
# get
# sspark.submit.pyFiles
# s
# e
#
# 2025-01-16 12:13:01,168 - py4j.clientserver - DEBUG - Answer received: !ys
# 2025-01-16 12:13:01,169 - py4j.clientserver - DEBUG - Command to send: r
# u
# org
# rj
# e
#
# 2025-01-16 12:13:01,171 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,172 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache
# rj
# e
#
# 2025-01-16 12:13:01,173 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,173 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark
# rj
# e
#
# 2025-01-16 12:13:01,174 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,174 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark.util
# rj
# e
#
# 2025-01-16 12:13:01,175 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,175 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark.util.Utils
# rj
# e
#
# 2025-01-16 12:13:01,178 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.util.Utils
# 2025-01-16 12:13:01,178 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.util.Utils
# getLocalDir
# e
#
# 2025-01-16 12:13:01,181 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,182 - py4j.clientserver - DEBUG - Command to send: c
# o27
# sc
# e
#
# 2025-01-16 12:13:01,182 - py4j.clientserver - DEBUG - Answer received: !yro32
# 2025-01-16 12:13:01,182 - py4j.clientserver - DEBUG - Command to send: c
# o32
# conf
# e
#
# 2025-01-16 12:13:01,183 - py4j.clientserver - DEBUG - Answer received: !yro33
# 2025-01-16 12:13:01,184 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.util.Utils
# getLocalDir
# ro33
# e
#
# 2025-01-16 12:13:01,184 - py4j.clientserver - DEBUG - Answer received: !ysC:\\Users\\trieu\\AppData\\Local\\Temp\\spark-b52c4ed4-e99c-40b7-b385-30a6d91daa27
# 2025-01-16 12:13:01,185 - py4j.clientserver - DEBUG - Command to send: r
# u
# org
# rj
# e
#
# 2025-01-16 12:13:01,188 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,189 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache
# rj
# e
#
# 2025-01-16 12:13:01,190 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,190 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark
# rj
# e
#
# 2025-01-16 12:13:01,191 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,192 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark.util
# rj
# e
#
# 2025-01-16 12:13:01,192 - py4j.clientserver - DEBUG - Answer received: !yp
# 2025-01-16 12:13:01,193 - py4j.clientserver - DEBUG - Command to send: r
# u
# org.apache.spark.util.Utils
# rj
# e
#
# 2025-01-16 12:13:01,193 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.util.Utils
# 2025-01-16 12:13:01,194 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.util.Utils
# createTempDir
# e
#
# 2025-01-16 12:13:01,194 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,194 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.util.Utils
# createTempDir
# sC:\\Users\\trieu\\AppData\\Local\\Temp\\spark-b52c4ed4-e99c-40b7-b385-30a6d91daa27
# spyspark
# e
#
# 2025-01-16 12:13:01,197 - py4j.clientserver - DEBUG - Answer received: !yro34
# 2025-01-16 12:13:01,198 - py4j.clientserver - DEBUG - Command to send: c
# o34
# getAbsolutePath
# e
#
# 2025-01-16 12:13:01,199 - py4j.clientserver - DEBUG - Answer received: !ysC:\\Users\\trieu\\AppData\\Local\\Temp\\spark-b52c4ed4-e99c-40b7-b385-30a6d91daa27\\pyspark-aabf429f-3540-41e7-be3f-910ecec18dfa
# 2025-01-16 12:13:01,199 - py4j.clientserver - DEBUG - Command to send: c
# o29
# get
# sspark.python.profile
# sfalse
# e
#
# 2025-01-16 12:13:01,200 - py4j.clientserver - DEBUG - Answer received: !ysfalse
# 2025-01-16 12:13:01,201 - py4j.clientserver - DEBUG - Command to send: c
# o29
# get
# sspark.python.profile.memory
# sfalse
# e
#
# 2025-01-16 12:13:01,201 - py4j.clientserver - DEBUG - Answer received: !ysfalse
# 2025-01-16 12:13:01,202 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 2025-01-16 12:13:01,227 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 2025-01-16 12:13:01,228 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# getDefaultSession
# e
#
# 2025-01-16 12:13:01,257 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,258 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# getDefaultSession
# e
#
# 2025-01-16 12:13:01,261 - py4j.clientserver - DEBUG - Answer received: !yro35
# 2025-01-16 12:13:01,261 - py4j.clientserver - DEBUG - Command to send: c
# o35
# isDefined
# e
#
# 2025-01-16 12:13:01,262 - py4j.clientserver - DEBUG - Answer received: !ybfalse
# 2025-01-16 12:13:01,263 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 2025-01-16 12:13:01,264 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 2025-01-16 12:13:01,265 - py4j.clientserver - DEBUG - Command to send: c
# o27
# sc
# e
#
# 2025-01-16 12:13:01,266 - py4j.clientserver - DEBUG - Answer received: !yro36
# 2025-01-16 12:13:01,266 - py4j.clientserver - DEBUG - Command to send: i
# java.util.HashMap
# e
#
# 2025-01-16 12:13:01,267 - py4j.clientserver - DEBUG - Answer received: !yao37
# 2025-01-16 12:13:01,267 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.app.name
# sYelpDataProcessor
# e
#
# 2025-01-16 12:13:01,268 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,268 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.sql.parquet.compression.codec
# ssnappy
# e
#
# 2025-01-16 12:13:01,270 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,270 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.sql.parquet.mergeSchema
# strue
# e
#
# 2025-01-16 12:13:01,271 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,272 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.sql.files.maxPartitionBytes
# s128MB
# e
#
# 2025-01-16 12:13:01,273 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,274 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.sql.shuffle.partitions
# s10
# e
#
# 2025-01-16 12:13:01,275 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,276 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.driver.memory
# s2g
# e
#
# 2025-01-16 12:13:01,276 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,277 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.executor.memory
# s2g
# e
#
# 2025-01-16 12:13:01,278 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,278 - py4j.clientserver - DEBUG - Command to send: c
# o37
# put
# sspark.default.parallelism
# s10
# e
#
# 2025-01-16 12:13:01,279 - py4j.clientserver - DEBUG - Answer received: !yn
# 2025-01-16 12:13:01,279 - py4j.clientserver - DEBUG - Command to send: i
# org.apache.spark.sql.SparkSession
# ro36
# ro37
# e
#
# 2025-01-16 12:13:01,333 - py4j.clientserver - DEBUG - Answer received: !yro38
# 2025-01-16 12:13:01,334 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 2025-01-16 12:13:01,335 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 2025-01-16 12:13:01,336 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# setDefaultSession
# e
#
# 2025-01-16 12:13:01,337 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,338 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# setDefaultSession
# ro38
# e
#
# 2025-01-16 12:13:01,339 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,339 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 2025-01-16 12:13:01,341 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 2025-01-16 12:13:01,341 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# setActiveSession
# e
#
# 2025-01-16 12:13:01,342 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:01,342 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# setActiveSession
# ro38
# e
#
# 2025-01-16 12:13:01,343 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,343 - __main__ - INFO - Spark Configuration:
# 2025-01-16 12:13:01,344 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkConf
# rj
# e
#
# 2025-01-16 12:13:01,344 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.SparkConf
# 2025-01-16 12:13:01,345 - py4j.clientserver - DEBUG - Command to send: i
# org.apache.spark.SparkConf
# bTrue
# e
#
# 2025-01-16 12:13:01,346 - py4j.clientserver - DEBUG - Answer received: !yro39
# 2025-01-16 12:13:01,347 - py4j.clientserver - DEBUG - Command to send: c
# o29
# getAll
# e
#
# 2025-01-16 12:13:01,348 - py4j.clientserver - DEBUG - Answer received: !yto40
# 2025-01-16 12:13:01,348 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,349 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,349 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i0
# e
#
# 2025-01-16 12:13:01,350 - py4j.clientserver - DEBUG - Answer received: !yro41
# 2025-01-16 12:13:01,350 - py4j.clientserver - DEBUG - Command to send: c
# o41
# _1
# e
#
# 2025-01-16 12:13:01,351 - py4j.clientserver - DEBUG - Answer received: !ysspark.app.submitTime
# 2025-01-16 12:13:01,352 - py4j.clientserver - DEBUG - Command to send: c
# o41
# _2
# e
#
# 2025-01-16 12:13:01,353 - py4j.clientserver - DEBUG - Answer received: !ys1737004379345
# 2025-01-16 12:13:01,353 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,354 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,354 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i1
# e
#
# 2025-01-16 12:13:01,355 - py4j.clientserver - DEBUG - Answer received: !yro42
# 2025-01-16 12:13:01,355 - py4j.clientserver - DEBUG - Command to send: c
# o42
# _1
# e
#
# 2025-01-16 12:13:01,356 - py4j.clientserver - DEBUG - Answer received: !ysspark.executor.memory
# 2025-01-16 12:13:01,356 - py4j.clientserver - DEBUG - Command to send: c
# o42
# _2
# e
#
# 2025-01-16 12:13:01,357 - py4j.clientserver - DEBUG - Answer received: !ys2g
# 2025-01-16 12:13:01,357 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,358 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,358 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i2
# e
#
# 2025-01-16 12:13:01,359 - py4j.clientserver - DEBUG - Answer received: !yro43
# 2025-01-16 12:13:01,360 - py4j.clientserver - DEBUG - Command to send: c
# o43
# _1
# e
#
# 2025-01-16 12:13:01,360 - py4j.clientserver - DEBUG - Answer received: !ysspark.driver.extraJavaOptions
# 2025-01-16 12:13:01,361 - py4j.clientserver - DEBUG - Command to send: c
# o43
# _2
# e
#
# 2025-01-16 12:13:01,361 - py4j.clientserver - DEBUG - Answer received: !ys-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false
# 2025-01-16 12:13:01,362 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,362 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,363 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i3
# e
#
# 2025-01-16 12:13:01,363 - py4j.clientserver - DEBUG - Answer received: !yro44
# 2025-01-16 12:13:01,364 - py4j.clientserver - DEBUG - Command to send: c
# o44
# _1
# e
#
# 2025-01-16 12:13:01,364 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.parquet.mergeSchema
# 2025-01-16 12:13:01,365 - py4j.clientserver - DEBUG - Command to send: c
# o44
# _2
# e
#
# 2025-01-16 12:13:01,365 - py4j.clientserver - DEBUG - Answer received: !ystrue
# 2025-01-16 12:13:01,366 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,366 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,367 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i4
# e
#
# 2025-01-16 12:13:01,367 - py4j.clientserver - DEBUG - Answer received: !yro45
# 2025-01-16 12:13:01,367 - py4j.clientserver - DEBUG - Command to send: c
# o45
# _1
# e
#
# 2025-01-16 12:13:01,368 - py4j.clientserver - DEBUG - Answer received: !ysspark.driver.host
# 2025-01-16 12:13:01,369 - py4j.clientserver - DEBUG - Command to send: c
# o45
# _2
# e
#
# 2025-01-16 12:13:01,370 - py4j.clientserver - DEBUG - Answer received: !ysOmen
# 2025-01-16 12:13:01,371 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,371 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,372 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i5
# e
#
# 2025-01-16 12:13:01,373 - py4j.clientserver - DEBUG - Answer received: !yro46
# 2025-01-16 12:13:01,373 - py4j.clientserver - DEBUG - Command to send: c
# o46
# _1
# e
#
# 2025-01-16 12:13:01,374 - py4j.clientserver - DEBUG - Answer received: !ysspark.executor.id
# 2025-01-16 12:13:01,374 - py4j.clientserver - DEBUG - Command to send: c
# o46
# _2
# e
#
# 2025-01-16 12:13:01,375 - py4j.clientserver - DEBUG - Answer received: !ysdriver
# 2025-01-16 12:13:01,375 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,376 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,376 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i6
# e
#
# 2025-01-16 12:13:01,377 - py4j.clientserver - DEBUG - Answer received: !yro47
# 2025-01-16 12:13:01,377 - py4j.clientserver - DEBUG - Command to send: c
# o47
# _1
# e
#
# 2025-01-16 12:13:01,378 - py4j.clientserver - DEBUG - Answer received: !ysspark.app.name
# 2025-01-16 12:13:01,378 - py4j.clientserver - DEBUG - Command to send: c
# o47
# _2
# e
#
# 2025-01-16 12:13:01,379 - py4j.clientserver - DEBUG - Answer received: !ysYelpDataProcessor
# 2025-01-16 12:13:01,379 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,380 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,381 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i7
# e
#
# 2025-01-16 12:13:01,381 - py4j.clientserver - DEBUG - Answer received: !yro48
# 2025-01-16 12:13:01,382 - py4j.clientserver - DEBUG - Command to send: c
# o48
# _1
# e
#
# 2025-01-16 12:13:01,382 - py4j.clientserver - DEBUG - Answer received: !ysspark.driver.port
# 2025-01-16 12:13:01,383 - py4j.clientserver - DEBUG - Command to send: c
# o48
# _2
# e
#
# 2025-01-16 12:13:01,383 - py4j.clientserver - DEBUG - Answer received: !ys49191
# 2025-01-16 12:13:01,384 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,384 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,384 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i8
# e
#
# 2025-01-16 12:13:01,385 - py4j.clientserver - DEBUG - Answer received: !yro49
# 2025-01-16 12:13:01,386 - py4j.clientserver - DEBUG - Command to send: c
# o49
# _1
# e
#
# 2025-01-16 12:13:01,387 - py4j.clientserver - DEBUG - Answer received: !ysspark.app.startTime
# 2025-01-16 12:13:01,387 - py4j.clientserver - DEBUG - Command to send: c
# o49
# _2
# e
#
# 2025-01-16 12:13:01,388 - py4j.clientserver - DEBUG - Answer received: !ys1737004379601
# 2025-01-16 12:13:01,388 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,389 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,390 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i9
# e
#
# 2025-01-16 12:13:01,391 - py4j.clientserver - DEBUG - Answer received: !yro50
# 2025-01-16 12:13:01,391 - py4j.clientserver - DEBUG - Command to send: c
# o50
# _1
# e
#
# 2025-01-16 12:13:01,392 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.shuffle.partitions
# 2025-01-16 12:13:01,392 - py4j.clientserver - DEBUG - Command to send: c
# o50
# _2
# e
#
# 2025-01-16 12:13:01,393 - py4j.clientserver - DEBUG - Answer received: !ys10
# 2025-01-16 12:13:01,393 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,394 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,394 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i10
# e
#
# 2025-01-16 12:13:01,395 - py4j.clientserver - DEBUG - Answer received: !yro51
# 2025-01-16 12:13:01,395 - py4j.clientserver - DEBUG - Command to send: c
# o51
# _1
# e
#
# 2025-01-16 12:13:01,396 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.parquet.compression.codec
# 2025-01-16 12:13:01,396 - py4j.clientserver - DEBUG - Command to send: c
# o51
# _2
# e
#
# 2025-01-16 12:13:01,397 - py4j.clientserver - DEBUG - Answer received: !yssnappy
# 2025-01-16 12:13:01,397 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,398 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,398 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i11
# e
#
# 2025-01-16 12:13:01,399 - py4j.clientserver - DEBUG - Answer received: !yro52
# 2025-01-16 12:13:01,399 - py4j.clientserver - DEBUG - Command to send: c
# o52
# _1
# e
#
# 2025-01-16 12:13:01,400 - py4j.clientserver - DEBUG - Answer received: !ysspark.app.id
# 2025-01-16 12:13:01,400 - py4j.clientserver - DEBUG - Command to send: c
# o52
# _2
# e
#
# 2025-01-16 12:13:01,401 - py4j.clientserver - DEBUG - Answer received: !yslocal-1737004380764
# 2025-01-16 12:13:01,401 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,403 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,403 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i12
# e
#
# 2025-01-16 12:13:01,404 - py4j.clientserver - DEBUG - Answer received: !yro53
# 2025-01-16 12:13:01,404 - py4j.clientserver - DEBUG - Command to send: c
# o53
# _1
# e
#
# 2025-01-16 12:13:01,406 - py4j.clientserver - DEBUG - Answer received: !ysspark.rdd.compress
# 2025-01-16 12:13:01,406 - py4j.clientserver - DEBUG - Command to send: c
# o53
# _2
# e
#
# 2025-01-16 12:13:01,407 - py4j.clientserver - DEBUG - Answer received: !ysTrue
# 2025-01-16 12:13:01,408 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,409 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,410 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i13
# e
#
# 2025-01-16 12:13:01,411 - py4j.clientserver - DEBUG - Answer received: !yro54
# 2025-01-16 12:13:01,412 - py4j.clientserver - DEBUG - Command to send: c
# o54
# _1
# e
#
# 2025-01-16 12:13:01,413 - py4j.clientserver - DEBUG - Answer received: !ysspark.default.parallelism
# 2025-01-16 12:13:01,414 - py4j.clientserver - DEBUG - Command to send: c
# o54
# _2
# e
#
# 2025-01-16 12:13:01,415 - py4j.clientserver - DEBUG - Answer received: !ys10
# 2025-01-16 12:13:01,415 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,417 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,417 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i14
# e
#
# 2025-01-16 12:13:01,420 - py4j.clientserver - DEBUG - Answer received: !yro55
# 2025-01-16 12:13:01,421 - py4j.clientserver - DEBUG - Command to send: c
# o55
# _1
# e
#
# 2025-01-16 12:13:01,422 - py4j.clientserver - DEBUG - Answer received: !ysspark.executor.extraJavaOptions
# 2025-01-16 12:13:01,422 - py4j.clientserver - DEBUG - Command to send: c
# o55
# _2
# e
#
# 2025-01-16 12:13:01,424 - py4j.clientserver - DEBUG - Answer received: !ys-Djava.net.preferIPv6Addresses=false -XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/jdk.internal.ref=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED -Djdk.reflect.useDirectMethodHandle=false
# 2025-01-16 12:13:01,447 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,449 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,450 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i15
# e
#
# 2025-01-16 12:13:01,451 - py4j.clientserver - DEBUG - Answer received: !yro56
# 2025-01-16 12:13:01,452 - py4j.clientserver - DEBUG - Command to send: m
# d
# o26
# e
#
# 2025-01-16 12:13:01,452 - py4j.clientserver - DEBUG - Command to send: c
# o56
# _1
# e
#
# 2025-01-16 12:13:01,455 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,455 - py4j.clientserver - DEBUG - Answer received: !ysspark.driver.memory
# 2025-01-16 12:13:01,457 - py4j.clientserver - DEBUG - Command to send: m
# d
# o28
# e
#
# 2025-01-16 12:13:01,458 - py4j.clientserver - DEBUG - Command to send: c
# o56
# _2
# e
#
# 2025-01-16 12:13:01,460 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,460 - py4j.clientserver - DEBUG - Answer received: !ys2g
# 2025-01-16 12:13:01,461 - py4j.clientserver - DEBUG - Command to send: m
# d
# o31
# e
#
# 2025-01-16 12:13:01,462 - py4j.clientserver - DEBUG - Command to send: a
# e
# o40
# e
#
# 2025-01-16 12:13:01,463 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,464 - py4j.clientserver - DEBUG - Answer received: !yi22
# 2025-01-16 12:13:01,465 - py4j.clientserver - DEBUG - Command to send: m
# d
# o32
# e
#
# 2025-01-16 12:13:01,465 - py4j.clientserver - DEBUG - Command to send: a
# g
# o40
# i16
# e
#
# 2025-01-16 12:13:01,467 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,467 - py4j.clientserver - DEBUG - Answer received: !yro57
# 2025-01-16 12:13:01,468 - py4j.clientserver - DEBUG - Command to send: m
# d
# o33
# e
#
# 2025-01-16 12:13:01,469 - py4j.clientserver - DEBUG - Command to send: c
# o57
# _1
# e
#
# 2025-01-16 12:13:01,471 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,472 - py4j.clientserver - DEBUG - Answer received: !ysspark.sql.files.maxPartitionBytes
# 2025-01-16 12:13:01,473 - py4j.clientserver - DEBUG - Command to send: m
# d
# o34
# e
#
# 2025-01-16 12:13:01,474 - py4j.clientserver - DEBUG - Command to send: c
# o57
# _2
# e
#
# 2025-01-16 12:13:01,475 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:01,476 - py4j.clientserver - DEBUG - Command to send: m
# d
# o35
# e
#
# ...
# 2025-01-16 12:13:07,207 - __main__ - INFO - Schema của DataFrame:
# 2025-01-16 12:13:07,208 - py4j.clientserver - DEBUG - Command to send: c
# o112
# schema
# e
#
# 2025-01-16 12:13:07,224 - py4j.clientserver - DEBUG - Answer received: !yro113
# 2025-01-16 12:13:07,225 - py4j.clientserver - DEBUG - Command to send: c
# o113
# treeString
# e
#
# 2025-01-16 12:13:07,229 - py4j.clientserver - DEBUG - Answer received: !ysroot\n |-- address: string (nullable = true)\n |-- attributes: struct (nullable = true)\n |    |-- AcceptsInsurance: string (nullable = true)\n |    |-- AgesAllowed: string (nullable = true)\n |    |-- Alcohol: string (nullable = true)\n |    |-- Ambience: string (nullable = true)\n |    |-- BYOB: string (nullable = true)\n |    |-- BYOBCorkage: string (nullable = true)\n |    |-- BestNights: string (nullable = true)\n |    |-- BikeParking: string (nullable = true)\n |    |-- BusinessAcceptsBitcoin: string (nullable = true)\n |    |-- BusinessAcceptsCreditCards: string (nullable = true)\n |    |-- BusinessParking: string (nullable = true)\n |    |-- ByAppointmentOnly: string (nullable = true)\n |    |-- Caters: string (nullable = true)\n |    |-- CoatCheck: string (nullable = true)\n |    |-- Corkage: string (nullable = true)\n |    |-- DietaryRestrictions: string (nullable = true)\n |    |-- DogsAllowed: string (nullable = true)\n |    |-- DriveThru: string (nullable = true)\n |    |-- GoodForDancing: string (nullable = true)\n |    |-- GoodForKids: string (nullable = true)\n |    |-- GoodForMeal: string (nullable = true)\n |    |-- HairSpecializesIn: string (nullable = true)\n |    |-- HappyHour: string (nullable = true)\n |    |-- HasTV: string (nullable = true)\n |    |-- Music: string (nullable = true)\n |    |-- NoiseLevel: string (nullable = true)\n |    |-- Open24Hours: string (nullable = true)\n |    |-- OutdoorSeating: string (nullable = true)\n |    |-- RestaurantsAttire: string (nullable = true)\n |    |-- RestaurantsDelivery: string (nullable = true)\n |    |-- RestaurantsGoodForGroups: string (nullable = true)\n |    |-- RestaurantsPriceRange2: string (nullable = true)\n |    |-- RestaurantsReservations: string (nullable = true)\n |    |-- RestaurantsTableService: string (nullable = true)\n |    |-- RestaurantsTakeOut: string (nullable = true)\n |    |-- Smoking: string (nullable = true)\n |    |-- WheelchairAccessible: string (nullable = true)\n |    |-- WiFi: string (nullable = true)\n |-- business_id: string (nullable = true)\n |-- categories: string (nullable = true)\n |-- city: string (nullable = true)\n |-- hours: struct (nullable = true)\n |    |-- Friday: string (nullable = true)\n |    |-- Monday: string (nullable = true)\n |    |-- Saturday: string (nullable = true)\n |    |-- Sunday: string (nullable = true)\n |    |-- Thursday: string (nullable = true)\n |    |-- Tuesday: string (nullable = true)\n |    |-- Wednesday: string (nullable = true)\n |-- is_open: long (nullable = true)\n |-- latitude: double (nullable = true)\n |-- longitude: double (nullable = true)\n |-- name: string (nullable = true)\n |-- postal_code: string (nullable = true)\n |-- review_count: long (nullable = true)\n |-- stars: double (nullable = true)\n |-- state: string (nullable = true)\n
# 2025-01-16 12:13:07,230 - py4j.clientserver - DEBUG - Command to send: c
# o38
# read
# e
#
# 2025-01-16 12:13:07,231 - py4j.clientserver - DEBUG - Answer received: !yro114
# 2025-01-16 12:13:07,232 - py4j.clientserver - DEBUG - Command to send: c
# o114
# option
# smultiLine
# sfalse
# e
#
# 2025-01-16 12:13:07,233 - py4j.clientserver - DEBUG - Answer received: !yro115
# 2025-01-16 12:13:07,234 - py4j.clientserver - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 2025-01-16 12:13:07,236 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 2025-01-16 12:13:07,237 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# toSeq
# e
#
# 2025-01-16 12:13:07,238 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:07,238 - py4j.clientserver - DEBUG - Command to send: i
# java.util.ArrayList
# e
#
# 2025-01-16 12:13:07,239 - py4j.clientserver - DEBUG - Answer received: !ylo116
# 2025-01-16 12:13:07,240 - py4j.clientserver - DEBUG - Command to send: c
# o116
# add
# sD:/Project/data/yelp_academic_dataset_business.json
# e
#
# 2025-01-16 12:13:07,240 - py4j.clientserver - DEBUG - Answer received: !ybtrue
# 2025-01-16 12:13:07,241 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# toSeq
# ro116
# e
#
# 2025-01-16 12:13:07,242 - py4j.clientserver - DEBUG - Answer received: !yro117
# 2025-01-16 12:13:07,243 - py4j.clientserver - DEBUG - Command to send: c
# o115
# json
# ro117
# e
# root
#  |-- address: string (nullable = true)
#  |-- attributes: struct (nullable = true)
#  |    |-- AcceptsInsurance: string (nullable = true)
#  |    |-- AgesAllowed: string (nullable = true)
#  |    |-- Alcohol: string (nullable = true)
#  |    |-- Ambience: string (nullable = true)
#  |    |-- BYOB: string (nullable = true)
#  |    |-- BYOBCorkage: string (nullable = true)
#  |    |-- BestNights: string (nullable = true)
#  |    |-- BikeParking: string (nullable = true)
#  |    |-- BusinessAcceptsBitcoin: string (nullable = true)
#  |    |-- BusinessAcceptsCreditCards: string (nullable = true)
#  |    |-- BusinessParking: string (nullable = true)
#  |    |-- ByAppointmentOnly: string (nullable = true)
#  |    |-- Caters: string (nullable = true)
#  |    |-- CoatCheck: string (nullable = true)
#  |    |-- Corkage: string (nullable = true)
#  |    |-- DietaryRestrictions: string (nullable = true)
#  |    |-- DogsAllowed: string (nullable = true)
#  |    |-- DriveThru: string (nullable = true)
#  |    |-- GoodForDancing: string (nullable = true)
#  |    |-- GoodForKids: string (nullable = true)
#  |    |-- GoodForMeal: string (nullable = true)
#  |    |-- HairSpecializesIn: string (nullable = true)
#  |    |-- HappyHour: string (nullable = true)
#  |    |-- HasTV: string (nullable = true)
#  |    |-- Music: string (nullable = true)
#  |    |-- NoiseLevel: string (nullable = true)
#  |    |-- Open24Hours: string (nullable = true)
#  |    |-- OutdoorSeating: string (nullable = true)
#  |    |-- RestaurantsAttire: string (nullable = true)
#  |    |-- RestaurantsDelivery: string (nullable = true)
#  |    |-- RestaurantsGoodForGroups: string (nullable = true)
#  |    |-- RestaurantsPriceRange2: string (nullable = true)
#  |    |-- RestaurantsReservations: string (nullable = true)
#  |    |-- RestaurantsTableService: string (nullable = true)
#  |    |-- RestaurantsTakeOut: string (nullable = true)
#  |    |-- Smoking: string (nullable = true)
#  |    |-- WheelchairAccessible: string (nullable = true)
#  |    |-- WiFi: string (nullable = true)
#  |-- business_id: string (nullable = true)
#  |-- categories: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- hours: struct (nullable = true)
#  |    |-- Friday: string (nullable = true)
#  |    |-- Monday: string (nullable = true)
#  |    |-- Saturday: string (nullable = true)
#  |    |-- Sunday: string (nullable = true)
#  |    |-- Thursday: string (nullable = true)
#  |    |-- Tuesday: string (nullable = true)
#  |    |-- Wednesday: string (nullable = true)
#  |-- is_open: long (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- longitude: double (nullable = true)
#  |-- name: string (nullable = true)
#  |-- postal_code: string (nullable = true)
#  |-- review_count: long (nullable = true)
#  |-- stars: double (nullable = true)
#  |-- state: string (nullable = true)
# 2025-01-16 12:13:07,563 - py4j.clientserver - DEBUG - Command to send: m
# d
# o116
# e
#
# 2025-01-16 12:13:07,564 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:08,406 - py4j.clientserver - DEBUG - Answer received: !yro118
# 2025-01-16 12:13:08,407 - py4j.clientserver - DEBUG - Command to send: c
# o118
# javaToPython
# e
#
# 2025-01-16 12:13:08,472 - py4j.clientserver - DEBUG - Answer received: !yro119
# 2025-01-16 12:13:08,473 - py4j.clientserver - DEBUG - Command to send: c
# o119
# id
# e
#
# 2025-01-16 12:13:08,478 - py4j.clientserver - DEBUG - Answer received: !yi13
# 2025-01-16 12:13:08,479 - py4j.clientserver - DEBUG - Command to send: c
# o119
# partitions
# e
#
# 2025-01-16 12:13:08,480 - py4j.clientserver - DEBUG - Answer received: !ylo120
# 2025-01-16 12:13:08,480 - py4j.clientserver - DEBUG - Command to send: c
# o120
# size
# e
#
# 2025-01-16 12:13:08,481 - py4j.clientserver - DEBUG - Answer received: !yi10
# 2025-01-16 12:13:08,482 - __main__ - INFO - Số lượng partitions: 10
# 2025-01-16 12:13:08,482 - py4j.clientserver - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 2025-01-16 12:13:08,489 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 2025-01-16 12:13:08,490 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# current_timestamp
# e
#
# 2025-01-16 12:13:08,495 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:08,496 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# current_timestamp
# e
#
# 2025-01-16 12:13:08,526 - py4j.clientserver - DEBUG - Answer received: !yro121
# 2025-01-16 12:13:08,527 - py4j.clientserver - DEBUG - Command to send: c
# o118
# withColumn
# singestion_timestamp
# ro121
# e
#
# 2025-01-16 12:13:08,565 - py4j.clientserver - DEBUG - Answer received: !yro122
# 2025-01-16 12:13:08,567 - py4j.clientserver - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 2025-01-16 12:13:08,571 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 2025-01-16 12:13:08,572 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# lit
# e
#
# 2025-01-16 12:13:08,573 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:08,574 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# lit
# sD:/Project/data/yelp_academic_dataset_business.json
# e
#
# 2025-01-16 12:13:08,575 - py4j.clientserver - DEBUG - Answer received: !yro123
# 2025-01-16 12:13:08,576 - py4j.clientserver - DEBUG - Command to send: c
# o122
# withColumn
# ssource_file
# ro123
# e
#
# 2025-01-16 12:13:08,614 - py4j.clientserver - DEBUG - Answer received: !yro124
# 2025-01-16 12:13:08,615 - py4j.clientserver - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 2025-01-16 12:13:08,618 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 2025-01-16 12:13:08,619 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# lit
# e
#
# 2025-01-16 12:13:08,621 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:08,622 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# lit
# s20250116_121308
# e
#
# 2025-01-16 12:13:08,624 - py4j.clientserver - DEBUG - Answer received: !yro125
# 2025-01-16 12:13:08,624 - py4j.clientserver - DEBUG - Command to send: c
# o124
# withColumn
# sbatch_id
# ro125
# e
#
# 2025-01-16 12:13:08,645 - py4j.clientserver - DEBUG - Answer received: !yro126
# 2025-01-16 12:13:08,646 - py4j.clientserver - DEBUG - Command to send: c
# o126
# count
# e
#
# 2025-01-16 12:13:09,989 - py4j.clientserver - DEBUG - Answer received: !yL150346
# 2025-01-16 12:13:09,990 - __main__ - INFO - Số lượng records: 150346
# 2025-01-16 12:13:09,990 - py4j.clientserver - DEBUG - Command to send: c
# o126
# write
# e
#
# 2025-01-16 12:13:10,007 - py4j.clientserver - DEBUG - Answer received: !yro127
# 2025-01-16 12:13:10,008 - py4j.clientserver - DEBUG - Command to send: c
# o127
# mode
# sappend
# e
#
# 2025-01-16 12:13:10,013 - py4j.clientserver - DEBUG - Answer received: !yro128
# 2025-01-16 12:13:10,014 - py4j.clientserver - DEBUG - Command to send: c
# o128
# format
# sparquet
# e
#
# 2025-01-16 12:13:10,016 - py4j.clientserver - DEBUG - Answer received: !yro129
# 2025-01-16 12:13:10,017 - py4j.clientserver - DEBUG - Command to send: c
# o129
# option
# scompression
# ssnappy
# e
#
# 2025-01-16 12:13:10,020 - py4j.clientserver - DEBUG - Answer received: !yro130
# 2025-01-16 12:13:10,021 - py4j.clientserver - DEBUG - Command to send: c
# o112
# write
# e
#
# 2025-01-16 12:13:10,038 - py4j.clientserver - DEBUG - Answer received: !yro131
# 2025-01-16 12:13:10,039 - py4j.clientserver - DEBUG - Command to send: c
# o131
# mode
# soverwrite
# e
#
# 2025-01-16 12:13:10,040 - py4j.clientserver - DEBUG - Answer received: !yro132
# 2025-01-16 12:13:10,042 - py4j.clientserver - DEBUG - Command to send: c
# o132
# format
# sparquet
# e
#
# 2025-01-16 12:13:10,044 - py4j.clientserver - DEBUG - Answer received: !yro133
# 2025-01-16 12:13:10,045 - py4j.clientserver - DEBUG - Command to send: c
# o133
# save
# sD:/Project/delta_lake/bronze/yelp_data/_test
# e
#
# 2025-01-16 12:13:13,973 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:13,974 - __main__ - INFO - Test write thành công, tiến hành lưu toàn bộ dữ liệu
# 2025-01-16 12:13:13,975 - py4j.clientserver - DEBUG - Command to send: c
# o130
# save
# sD:/Project/delta_lake/bronze/yelp_data/
# e
#
# 2025-01-16 12:13:16,349 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:16,350 - py4j.clientserver - DEBUG - Command to send: c
# o38
# read
# e
#
# 2025-01-16 12:13:16,351 - py4j.clientserver - DEBUG - Answer received: !yro134
# 2025-01-16 12:13:16,352 - py4j.clientserver - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 2025-01-16 12:13:16,355 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 2025-01-16 12:13:16,356 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# toSeq
# e
#
# 2025-01-16 12:13:16,356 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:16,357 - py4j.clientserver - DEBUG - Command to send: i
# java.util.ArrayList
# e
#
# 2025-01-16 12:13:16,358 - py4j.clientserver - DEBUG - Answer received: !ylo135
# 2025-01-16 12:13:16,359 - py4j.clientserver - DEBUG - Command to send: c
# o135
# add
# sD:/Project/delta_lake/bronze/yelp_data/
# e
#
# 2025-01-16 12:13:16,360 - py4j.clientserver - DEBUG - Answer received: !ybtrue
# 2025-01-16 12:13:16,361 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# toSeq
# ro135
# e
#
# 2025-01-16 12:13:16,362 - py4j.clientserver - DEBUG - Answer received: !yro136
# 2025-01-16 12:13:16,363 - py4j.clientserver - DEBUG - Command to send: c
# o134
# parquet
# ro136
# e
#
# 2025-01-16 12:13:16,625 - py4j.clientserver - DEBUG - Command to send: m
# d
# o135
# e
#
# 2025-01-16 12:13:16,636 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:16,778 - py4j.clientserver - DEBUG - Answer received: !yro137
# 2025-01-16 12:13:16,780 - py4j.clientserver - DEBUG - Command to send: c
# o137
# count
# e
#
# 2025-01-16 12:13:17,203 - py4j.clientserver - DEBUG - Answer received: !yL150346
# 2025-01-16 12:13:17,204 - __main__ - INFO - Đã xử lý và lưu thành công 150346 records
# 2025-01-16 12:13:17,205 - py4j.clientserver - DEBUG - Command to send: c
# o27
# stop
# e
#
# 2025-01-16 12:13:17,331 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:17,419 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 2025-01-16 12:13:17,421 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 2025-01-16 12:13:17,422 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# clearDefaultSession
# e
#
# 2025-01-16 12:13:17,423 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:17,423 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# clearDefaultSession
# e
#
# 2025-01-16 12:13:17,424 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:17,424 - py4j.clientserver - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 2025-01-16 12:13:17,426 - py4j.clientserver - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 2025-01-16 12:13:17,427 - py4j.clientserver - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# clearActiveSession
# e
#
# 2025-01-16 12:13:17,428 - py4j.clientserver - DEBUG - Answer received: !ym
# 2025-01-16 12:13:17,428 - py4j.clientserver - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# clearActiveSession
# e
#
# 2025-01-16 12:13:17,429 - py4j.clientserver - DEBUG - Answer received: !yv
# 2025-01-16 12:13:17,430 - __main__ - INFO - Đã dừng SparkSession

# %%
input_path = "D:/Project/data/yelp_academic_dataset_business.json"
output_path = "D:/Project/delta_lake/bronze/yelp_data/"
